# %% [markdown]
# ## Regression Analysis Notebook
#
# This notebook contains a regression analysis project.  I approached a situation like ________ / I asked the question:  ________.  **Elaborate on your business context / question that you approached your analysis with.  If there's an easy visualization you can use to demonstrate the problem you're investigating, include it.**
#
# Data used:
#
# Analyses performed:
#
#     EDA
#         - specific variables constructed
#
#         - specific variables compared
#
#         - results
#             - what things did you find?
#
#         - graphics
#
#     Regression Modeling
#         - First model
#             what variables are included in this model?
#             what are the models results?  How do these results inform the initial question you asked?
#         - Second model
#             how was this model different from the previous models?
#             what are the models results?  How do these results inform the initial question you asked?
#
#         - Third model, etc.
#
# Overall recommendations:
#
#     - List the specific recommendations for someone looking for information about your question in order to decide what to do
#
#
# The rest of the book contains the actual steps of the data analysis.  Each section of the book is separated by markdown texts, which follow the table of contents below:
#
# ## Data acquisition / Cleaning
#
#
# ### Importing libraries
# ### Reading in the data
# ## Train / Test Split
# ### Cleaning the data
# #### Fixing nulls
# #### Outliers
# #### Scaling
# ### Feature Engineering
# #### Creating specific features
# #### Feature 1
# #### Feature 2 (etc.)
#
#
# ## EDA
# ### Investigating specific relationship 1
# ### graphic
# ### Investigating specific relationship 2
# ### graphic (etc)
#
# ## Modeling
# ### Model 1 (MVP)
# ### Model 2
# ### Model 3 (etc.)
#
# ## Analysis
# Pull all of your results together.  What have you found that would be useful to someone facing the question you were investingating?  Discuss all results, from data cleaning caveats to EDA to Modeling.
#
#
#
# **Notes:
#
#     - if this structure looks familiar, it should!  It's the structure you used for your presentations.  Bascially, this walkthrough at the top of the book is a version of your presentation with more information in it.  For example, instead of restricting your discussion of EDA results to the one or two most interesting things, list everything you did.
#
#     - Use the above table of contents to separate out the steps of your notebook, if you haven't already.  The goal is for you to do this kind of organization **as you're doing your analysis**.  This will help you structure your notebook so you don't get confused when you're running multiple cells, and will help keep you on track as you work.
#
#     - If you have other sections you think you need signposts for, good!  Include them.
