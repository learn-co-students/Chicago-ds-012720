# %% [markdown]
# ![sql](img/sql-logo.jpg)
#
# # A beginner's guide to databases, SQL, & using them with `pandas`

# %% [markdown]
# **Scenario:** You are a data analyst for the Homeland Security, trying to create reports on the active airports world wide. The data you need to access is in a SQL database. YOu need to be able to query for the data in a database!

# %% [markdown]
# Activation: Here are a bunch of tools and concepts. Let's make three bins for data analyst, data scientist, and data engineer on the board.  Put the words in a bin. They can go in multiple bins.

# %% [markdown]
# words = [python, sql, predictions, eda, machine learning, ai, pyspark, hadoop, tableau, relational database, jupyter notebook, aws, nosql, pipeline, recommendation system, data lake]

# %% [markdown]
# ## Learning goals:
# - Goal 1: Summarize the use case for sql in the data science skill set
# - Goal 2: Define key sql terminology
# - Goal 3: Use basic SQL commands:
#     - Construct SQL queries
#     - Use JOIN to merge tables along logical columns
#     - Grouping Data with SQL
# - Goal 4: Convert SQL to pandas

# %% [markdown]
# ## Goal 1: Summarize
#
# To date the data we've seen has looked like [this.](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm)
#
# That is how we need data to look to run analysis and build models.<br>
# But it doesn't _live_ there in it's native state.

# %% [markdown]
# [Netflix has a great article](https://medium.com/netflix-techblog/notebook-innovation-591ee3221233) describing three different data roles at their company, their different needs, and their toolsets.
#
# ![netflix](img/netflix-data-roles.jpeg)
#
# Examining that graphic, SQL shows up as one of the tools of the _Data Engineer_

# %% [markdown]
# Data Engineers provide the essential data architecture services that make data science possible.
#
# ![hierarchy](img/ai-hierachy.png)
#
# [Source: Monica Rogati’s fantastic Medium post “The AI Hierarchy of Needs”
# ](https://hackernoon.com/the-ai-hierarchy-of-needs-18f111fcc007)

# %% [markdown]
# ## What does it mean to **Engineer Data**?
#
# Let's start with a basic scenario:<br>
# You are HR. You have *no* current database.
# How would you set it up?
#
# Data needs considerations:
# - What you want to store
# - What "views" you anticipate wanting in the future
#
# Structure considerations:
# - Speed of retrieval
# - How much data you are accessing
# - How much you are storing

# %% [markdown]
# ![etl](img/etl.png)
#
# [img source: Jeff Hammerbacher’s slide from UC Berkeley CS 194 course ](https://bcourses.berkeley.edu/courses/1377158/pages/cs-194-16-introduction-to-data-science-fall-2015)

# %% [markdown]
# ### What is a Relational Database?
#
# ![rdb](img/relational-dbms-model.png)
# [reference for image ](https://www.studytonight.com/dbms/database-model.php)

# %% [markdown]
# ### POPULAR RDBMS
#
# - SQLite
# - MySQL
# - PostgreSql
# - Oracle DB
# - SQL Server

# %% [markdown]
# ***
# ### SQL
#
# [History of SQL](https://www.businessnewsdaily.com/5804-what-is-sql.html)
#
# > Future users of large data banks must be protected from having to know how the data is organized in the machine (the internal representation). A prompting service which supplies such information is not a satisfactory solution. Activities of users at terminals and most application programs should remain unaffected when the internal representation of data is changed and even when some aspects of the external representation are changed. Changes in data representation will often be needed as a result of changes in query, update, and report traffic and natural growth in the types of stored information.
# .
# .
# .<br>
# <br>
# In Section 1 a relational model of data is proposed as a basis for protecting users of formatted data systems from the potentially disruptive changes in data representation caused by growth in the data bank and changes in traffic.
#
# [The original SQL paper from the 1970s.](https://www.seas.upenn.edu/~zives/03f/cis550/codd.pdf)

# %% [markdown]
# ***
# ## Goal 2: Database terminology
#
# ### Relational Database Schema
#
# ![schema](img/MySQL_Schema_Music_Example.png)
#
# [source of image](https://database.guide/what-is-a-database-schema/)

# %% [markdown]
# ### Table columns view
# <img src="img/columns.png" width=650>

# %% [markdown]
# ### Terminology
#
# - Database
# - Schema
# - Queries
# - Tables
# - Views
# - Primary Keys
# - Foreign Keys
# - Indexes
# - Functions & User Defined Functions (UDFs)

# %% [markdown]
# ***
# ### SQLite
#
# <img src="img/SQLite-Python.jpg" width=650>
#
# "SQLite is a C library that provides a lightweight disk-based database that doesn’t require a separate server process and allows accessing the database using a nonstandard variant of the SQL query language. Some applications can use SQLite for internal data storage. It’s also possible to prototype an application using SQLite and then port the code to a larger database such as PostgreSQL or Oracle." - [sqlite documentation](https://docs.python.org/2/library/sqlite3.html)

# %% [markdown]
# ## But what about connecting to database servers?
#
# To connect to other database types there are many different libraries:
# - Oracle: [cx_Oracle](https://oracle.github.io/python-cx_Oracle/)
# - MySQL: [MySQL-python](https://github.com/farcepest/MySQLdb1)
# - PostgreSQL: [Psycopg2](http://initd.org/psycopg/docs/)
# - Microsoft SQL Server: [pymssql](http://www.pymssql.org/en/stable/)
#
# These all implement [PEP 249: DB API v2](https://www.python.org/dev/peps/pep-0249/)

# %% [markdown]
# ***
# ## Goal 3: Get going with sqlite!

# %%
import sqlite3

# %% [markdown]
# #### Load a DB object with `connect` and `cursor`

# %%
con = sqlite3.connect('data/flights.db')
cursor = con.cursor()

# %% [markdown]
# #### Get information about one table
#
# **A note about** `execute`<br>
# Each time you use it, you reset the value of cursor

# %%
cursor.execute("SELECT * FROM airports as a").fetchone()
# Out:
# (0,
#  '1',
#  'Goroka',
#  'Goroka',
#  'Papua New Guinea',
#  'GKA',
#  'AYGA',
#  '-6.081689',
#  '145.391881',
#  '5282',
#  '10',
#  'U',
#  'Pacific/Port_Moresby')

# %%
cursor.fetchone()
# Out:
# (1,
#  '2',
#  'Madang',
#  'Madang',
#  'Papua New Guinea',
#  'MAG',
#  'AYMD',
#  '-5.207083',
#  '145.7887',
#  '20',
#  '10',
#  'U',
#  'Pacific/Port_Moresby')

# %%
cursor.fetchmany(4)
# Out:
# [(2,
#   '3',
#   'Mount Hagen',
#   'Mount Hagen',
#   'Papua New Guinea',
#   'HGU',
#   'AYMH',
#   '-5.826789',
#   '144.295861',
#   '5388',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (3,
#   '4',
#   'Nadzab',
#   'Nadzab',
#   'Papua New Guinea',
#   'LAE',
#   'AYNZ',
#   '-6.569828',
#   '146.726242',
#   '239',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (4,
#   '5',
#   'Port Moresby Jacksons Intl',
#   'Port Moresby',
#   'Papua New Guinea',
#   'POM',
#   'AYPY',
#   '-9.443383',
#   '147.22005',
#   '146',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (5,
#   '6',
#   'Wewak Intl',
#   'Wewak',
#   'Papua New Guinea',
#   'WWK',
#   'AYWK',
#   '-3.583828',
#   '143.669186',
#   '19',
#   '10',
#   'U',
#   'Pacific/Port_Moresby')]

# %% [markdown]
# #### Use description

# %%
cursor.description
# Out:
# (('index', None, None, None, None, None, None),
#  ('id', None, None, None, None, None, None),
#  ('name', None, None, None, None, None, None),
#  ('city', None, None, None, None, None, None),
#  ('country', None, None, None, None, None, None),
#  ('code', None, None, None, None, None, None),
#  ('icao', None, None, None, None, None, None),
#  ('latitude', None, None, None, None, None, None),
#  ('longitude', None, None, None, None, None, None),
#  ('altitude', None, None, None, None, None, None),
#  ('offset', None, None, None, None, None, None),
#  ('dst', None, None, None, None, None, None),
#  ('timezone', None, None, None, None, None, None))

# %% [markdown]
# ***
# ## Goal 3: Use basic SQL commands
# - Construct SQL queries
# - Use JOIN to merge tables along logical columns
# - Grouping Data with SQL

# %% [markdown]
# ![](img/flight_schema.png)

# %%
import sqlite3
con = sqlite3.connect('data/flights.db')
cursor = con.cursor()

# %% [markdown]
# ## SELECT and FROM

# %% [markdown]
# SELECT and FROM
# The SELECT statement is followed by the names of the  fields from the table specified by the FROM statement.
#
# Let's select all the columns from the airlines table

# %%
cursor.execute("""
SELECT *
FROM airlines
""")
cursor.fetchmany(5)
# Out:
# [(0, '1', 'Private flight', '\\N', '-', None, None, None, 'Y'),
#  (1, '2', '135 Airways', '\\N', None, 'GNL', 'GENERAL', 'United States', 'N'),
#  (2, '3', '1Time Airline', '\\N', '1T', 'RNX', 'NEXTIME', 'South Africa', 'Y'),
#  (3,
#   '4',
#   '2 Sqn No 1 Elementary Flying Training School',
#   '\\N',
#   None,
#   'WYT',
#   None,
#   'United Kingdom',
#   'N'),
#  (4, '5', '213 Flight Unit', '\\N', None, 'TFU', None, 'Russia', 'N')]

# %% [markdown]
# ## Your turn
#
# Use SELECT and FROM to fetch only the name and city from the airports table.
# **Note: separate the column names with a comma**

# %%
cursor.execute("""

""")
cursor.fetchmany(5)
# Out:
# []

# %% [markdown]
# ## WHERE

# %% [markdown]
# The WHERE clause comes after SELECT, and is used to filter our queries based on some specified criteria.
#
# Let's select the name and country of all airports in the United Kingdom.

# %%
cursor.execute("""
SELECT  name, country
FROM airports
WHERE country = 'United Kingdom'
""")
cursor.fetchmany()
# Out:
# [('Belfast Intl', 'United Kingdom')]

# %% [markdown]
# ## More WHERE:<br>
# Along with `=`, can also use `between`, `in`, wildcards `%`, `AND`, `OR`, `NOT`
#
# ### Your turn
# SELECT the name, country, for all **active** airlines in the United States

# %%
cursor.execute("""

""")
cursor.fetchmany(10)
# Out:
# []

# %% [markdown]
# ## LIKE and %

# %% [markdown]
# Let's use **LIKE** and the % operator to
# SELECT name and country for **active** airlines in the United States which begin with A

# %%
cursor.execute("""
SELECT name, country FROM airlines
WHERE active = 'Y'
AND country = 'United States'
AND name LIKE 'A%'
""")
cursor.fetchmany(10)
# Out:
# [('Aloha Airlines', 'United States'),
#  ('American Airlines', 'United States'),
#  ('Allegiant Air', 'United States'),
#  ('Alaska Central Express', 'United States'),
#  ('Air Cargo Carriers', 'United States'),
#  ('Airlift International', 'United States'),
#  ('America West Airlines', 'United States'),
#  ('Air Wisconsin', 'United States'),
#  ('Allegheny Commuter Airlines', 'United States'),
#  ('Air Sunshine', 'United States')]

# %% [markdown]
# ## ORDER BY
# The ORDER BY clause sorts the data by a specified field.  We can specify ascending and descending by passing ASC and DESC.
#
# Let's order all the airport codes in reverse alphabetical order.

# %%
cursor.execute("""
SELECT code, name FROM airports
ORDER BY code DESC
""")
cursor.fetchmany(10)
# Out:
# [('ИКУ', 'Issyk-Kul International Airport'),
#  ('ZZU', 'Mzuzu'),
#  ('ZYR', 'Brussels Gare du Midi'),
#  ('ZYP', 'Penn Station'),
#  ('ZYL', 'Osmany Intl'),
#  ('ZYA', 'Amsterdam Centraal'),
#  ('ZYA', 'Amsterdam Centraal'),
#  ('ZXE', 'Edinburgh Waverly Station'),
#  ('ZXB', 'Jan Mayensfield'),
#  ('ZWU', 'Washington Union Station')]

# %% [markdown]
# ## Your turn
#
# Fetch source and destination from routes and ORDER BY airline in ascending order

# %%
cursor.execute("""

""")
cursor.fetchmany(10)
# Out:
# []

# %% [markdown]
# ## LIMIT
# Instead of returning all of the results of a query, we can LIMIT the number by a certain amount.  We put the LIMIT clause at the end.
#
# Update your previous query to only return 1 result.

# %% [markdown]
# ## DISTINCT
#
# If you want to look at unique values of a certain field, use DISTINCT in the select clause.
#
# Select the unique countries from our airports table ordered alphabetically.  Limit the result to 10

# %%
cursor.execute("""
SELECT DISTINCT(country) FROM airports
ORDER BY country ASC
LIMIT 10
""")
cursor.fetchall()
# Out:
# [('Afghanistan',),
#  ('Albania',),
#  ('Algeria',),
#  ('American Samoa',),
#  ('Angola',),
#  ('Anguilla',),
#  ('Antarctica',),
#  ('Antigua and Barbuda',),
#  ('Argentina',),
#  ('Armenia',)]

# %% [markdown]
# ## Your turn
# SELECT DISTINCT airlines from our airlines table, limit results to 5.

# %%
cursor.execute("""

""")
cursor.fetchmany(10)
# Out:
# []

# %% [markdown]
# ## Aliases
#
# Aliases can be used for both columns and tables.  Once defined, the aliases can be used to reference the value in other parts of the query.

# %%
cursor.execute("""
SELECT name as n, country as c 
FROM airlines a
WHERE active = 'Y'
AND c = 'United States'
AND n LIKE 'A%'
""")
cursor.fetchmany(10)
# Out:
# [('Aloha Airlines', 'United States'),
#  ('American Airlines', 'United States'),
#  ('Allegiant Air', 'United States'),
#  ('Alaska Central Express', 'United States'),
#  ('Air Cargo Carriers', 'United States'),
#  ('Airlift International', 'United States'),
#  ('America West Airlines', 'United States'),
#  ('Air Wisconsin', 'United States'),
#  ('Allegheny Commuter Airlines', 'United States'),
#  ('Air Sunshine', 'United States')]

# %% [markdown]
# Aliasing the table names becomes very useful when joins are introduced, so let's introduce them

# %% [markdown]
# ### SQL Joins

# %% [markdown]
# SQL joins can be used to both **add** data to a table and **remove** data from a table.

# %% [markdown]
# <img src="img/venn.png" width=550>

# %% [markdown]
# We have to rely on the schema to specify what column the tables join on.

# %% [markdown]
# **Task** Write a query that will join the latitude and longitude data from the airports table to the information on the routes table

# %%
cursor.execute("""
SELECT DISTINCT source, latitude, longitude
FROM airports a
JOIN routes r
ON a.id = r.source_id
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('GKA', '-6.081689', '145.391881')
# ('MAG', '-5.207083', '145.7887')
# ('HGU', '-5.826789', '144.295861')
# ('LAE', '-6.569828', '146.726242')
# ('POM', '-9.443383', '147.22005')
# ('WWK', '-3.583828', '143.669186')
# ('UAK', '61.160517', '-45.425978')
# ('GOH', '64.190922', '-51.678064')
# ('SFJ', '67.016969', '-50.689325')
# ('THU', '76.531203', '-68.703161')
# ('AEY', '65.659994', '-18.072703')
# ('EGS', '65.283333', '-14.401389')
# ('IFJ', '66.058056', '-23.135278')
# ('KEF', '63.985', '-22.605556')
# ('RKV', '64.13', '-21.940556')
# ('YAM', '46.485001', '-84.509445')
# ('YAY', '51.391944', '-56.083056')
# ('YBC', '49.1325', '-68.204444')
# ('YBG', '48.330555', '-70.996391')
# ('YBK', '64.298889', '-96.077778')
# ('YBL', '49.950832', '-125.270833')
# ('YBR', '49.91', '-99.951944')
# ('YCB', '69.108055', '-105.138333')
# ('YCD', '49.052333', '-123.870167')
# ('YCG', '49.296389', '-117.6325')
# ('YCL', '47.990833', '-66.330278')
# ('YCO', '67.816667', '-115.143889')
# ('YCY', '70.486111', '-68.516667')
# ('YZS', '64.193333', '-83.359444')
# ('YDF', '49.210833', '-57.391388')
# ('YDQ', '55.742333', '-120.183')
# ('YEG', '53.309723', '-113.579722')
# ('YEK', '61.094166', '-94.070833')
# ('YEV', '68.304167', '-133.482778')
# ('YFB', '63.75639', '-68.555832')
# ('YFC', '45.868889', '-66.537222')
# ('YFO', '54.678055', '-101.681667')
# ('YFS', '61.760153', '-121.236525')
# ('YGK', '44.225277', '-76.596944')
# ('YGL', '53.625278', '-77.704167')
# ('YGP', '48.775278', '-64.478611')
# ('YGR', '47.424721', '-61.778056')
# ('YHD', '49.831667', '-92.744167')
# ('YHI', '70.762778', '-117.806111')
# ('YHK', '68.635556', '-95.849722')
# ('YHM', '43.173611', '-79.935')
# ('YHU', '45.5175', '-73.416944')
# ('YHY', '60.839722', '-115.782778')
# ('YHZ', '44.880833', '-63.50861')
# ('YIO', '72.683334', '-77.966667')
# ('YJT', '48.544167', '-58.549999')
# ('YKA', '50.702222', '-120.444444')
# ('YKF', '43.460833', '-80.378611')
# ('YKL', '54.805278', '-66.805278')
# ('YLL', '53.309166', '-110.0725')
# ('YLW', '49.956112', '-119.377778')
# ('YMM', '56.653333', '-111.221944')
# ('YMO', '51.291111', '-80.607778')
# ('YNA', '50.19', '-61.789167')
# ('YOJ', '58.621389', '-117.164722')
# ('YOW', '45.3225', '-75.669167')
# ('YPL', '51.446388', '-90.214167')
# ('YPN', '49.836389', '-64.288611')
# ('YPR', '54.28611', '-130.444722')
# ('YPY', '58.767223', '-111.117222')
# ('YQB', '46.791111', '-71.393333')
# ('YQF', '52.182222', '-113.894444')
# ('YQG', '42.275556', '-82.955556')
# ('YQK', '49.788334', '-94.363056')
# ('YQL', '49.630278', '-112.799722')
# ('YQM', '46.112221', '-64.678611')
# ('YQQ', '49.710833', '-124.886667')
# ('YQR', '50.431944', '-104.665833')
# ('YQT', '48.371944', '-89.323889')
# ('YQU', '55.179722', '-118.885')
# ('YQX', '48.936944', '-54.568056')
# ('YQY', '46.161388', '-60.047779')
# ('YQZ', '53.026112', '-122.510278')
# ('YRB', '74.716944', '-94.969444')
# ('YRT', '62.81139', '-92.115833')
# ('YSB', '46.625', '-80.798889')
# ('YSJ', '45.316111', '-65.890278')
# ('YSM', '60.020278', '-111.961944')
# ('YSY', '71.993889', '-125.2425')
# ('YTE', '64.23', '-76.526667')
# ('YTH', '55.801111', '-97.864166')
# ('YTS', '48.569721', '-81.376667')
# ('YTZ', '43.627499', '-79.396167')
# ('YUB', '69.433334', '-133.026389')
# ('YUL', '45.470556', '-73.740833')
# ('YUT', '66.521389', '-86.224722')
# ('YUX', '68.776111', '-81.243611')
# ('YUY', '48.206111', '-78.835556')
# ('YVM', '67.545833', '-64.031389')
# ('YVO', '48.053333', '-77.782778')
# ('YVP', '58.096111', '-68.426944')
# ('YVQ', '65.281617', '-126.798219')
# ('YVR', '49.193889', '-123.184444')
# ('YWG', '49.910036', '-97.239886')
# ('YWK', '52.921944', '-66.864444')
# ('YWL', '52.183056', '-122.054167')
# ('YXC', '49.612222', '-115.781944')
# ('YXE', '52.170834', '-106.699722')
# ('YXH', '50.01889', '-110.720833')
# ('YXJ', '56.238056', '-120.740278')
# ('YXL', '50.113889', '-91.905278')
# ('YXP', '66.145', '-65.713611')
# ('YXS', '53.889444', '-122.678889')
# ('YXT', '54.468508', '-128.576219')
# ('YXU', '43.033056', '-81.151111')
# ('YXX', '49.025278', '-122.360556')
# ('YXY', '60.709553', '-135.067269')
# ('YYB', '46.363611', '-79.422778')
# ('YYC', '51.113888', '-114.020278')
# ('YYD', '54.824722', '-127.182778')
# ('YYE', '58.836389', '-122.596944')
# ('YYF', '49.463056', '-119.602222')
# ('YYG', '46.290001', '-63.121111')
# ('YYH', '69.546667', '-93.576667')
# ('YYJ', '48.646944', '-123.425833')
# ('YYQ', '58.739167', '-94.065')
# ('YYR', '53.319168', '-60.425833')
# ('YYT', '47.61861', '-52.751945')
# ('YYU', '49.413889', '-82.4675')
# ('YYY', '48.608612', '-68.208056')
# ('YYZ', '43.677223', '-79.630556')
# ('YZF', '62.462778', '-114.440278')
# ('YZP', '53.254333', '-131.813833')
# ('YZR', '42.999444', '-82.308889')
# ('YZT', '50.680556', '-127.366667')
# ('YZV', '50.223333', '-66.265556')
# ('ZFM', '67.4075', '-134.860556')
# ('BJA', '36.711997', '5.069922')
# ('ALG', '36.691014', '3.215408')
# ('DJG', '24.292767', '9.452444')
# ('TMR', '22.811461', '5.451075')
# ('AAE', '36.822225', '7.809167')
# ('CZL', '36.276028', '6.620386')
# ('TEE', '35.431611', '8.120717')
# ('HRM', '32.930431', '3.311542')
# ('TID', '35.341136', '1.463147')
# ('TLM', '35.016667', '-1.45')
# ('ORN', '35.623858', '-0.621183')
# ('MUW', '35.207725', '0.147142')
# ('AZR', '27.837589', '-0.186414')
# ('BSK', '34.793289', '5.738231')
# ('ELG', '30.571294', '2.859586')
# ('GHA', '32.384106', '3.794114')
# ('HME', '31.672972', '6.140444')
# ('INZ', '27.251022', '2.512017')
# ('TGR', '33.067803', '6.088672')
# ('OGX', '31.917223', '5.412778')
# ('IAM', '28.05155', '9.642911')
# ('COO', '6.357228', '2.384353')
# ('OUA', '12.353194', '-1.512417')
# ('BOY', '11.160056', '-4.330969')
# ('ACC', '5.605186', '-0.166786')
# ('TML', '9.557192', '-0.863214')
# ('NYI', '7.361828', '-2.328756')
# ('TKD', '4.896056', '-1.774756')
# ('ABJ', '5.261386', '-3.926294')
# ('ABV', '9.006792', '7.263172')
# ('BNI', '6.316981', '5.599503')
# ('CBQ', '4.976019', '8.347197')
# ('ENU', '6.474272', '7.561961')
# ('IBA', '7.362458', '3.978333')
# ('ILR', '8.440211', '4.493919')
# ('JOS', '9.639828', '8.86905')
# ('KAD', '10.696025', '7.320114')
# ('KAN', '12.047589', '8.524622')
# ('LOS', '6.577369', '3.321156')
# ('PHC', '5.015494', '6.949594')
# ('SKO', '12.916322', '5.207189')
# ('YOL', '9.257553', '12.430422')
# ('NIM', '13.481547', '2.183614')
# ('MIR', '35.758056', '10.754722')
# ('TUN', '36.851033', '10.227217')
# ('GAF', '34.422022', '8.822503')
# ('GAE', '33.876919', '10.103333')
# ('DJE', '33.875031', '10.775461')
# ('SFA', '34.717953', '10.690972')
# ('TOE', '33.939722', '8.110556')
# ('LFW', '6.165611', '1.254511')
# ('ANR', '51.189444', '4.460278')
# ('BRU', '50.901389', '4.484444')
# ('CRL', '50.459197', '4.453817')
# ('LGG', '50.637417', '5.443222')
# ('OST', '51.198889', '2.862222')
# ('SXF', '52.380001', '13.5225')
# ('DRS', '51.132767', '13.767161')
# ('ERF', '50.979811', '10.958106')
# ('FRA', '50.026421', '8.543125')
# ('FMO', '52.134642', '7.684831')
# ('HAM', '53.630389', '9.988228')
# ('CGN', '50.865917', '7.142744')
# ('DUS', '51.289453', '6.766775')
# ('MUC', '48.353783', '11.786086')
# ('NUE', '49.4987', '11.066897')
# ('LEJ', '51.432447', '12.241633')
# ('SCN', '49.214553', '7.109508')
# ('STR', '48.689878', '9.221964')
# ('TXL', '52.559686', '13.287711')
# ('HAJ', '52.461056', '9.685078')
# ('BRE', '53.0475', '8.786667')
# ('HHN', '49.948672', '7.263892')
# ('MHG', '49.472706', '8.514264')
# ('XFW', '53.535886', '9.837025')
# ('LBC', '53.805367', '10.719222')
# ('PAD', '51.614089', '8.616317')
# ('DTM', '51.518314', '7.612242')
# ('AGB', '48.425158', '10.931764')
# ('FDH', '47.671317', '9.511486')
# ('KSF', '51.408394', '9.377631')
# ('GWT', '54.91325', '8.340472')
# ('URE', '58.229883', '22.509494')
# ('TLL', '59.413317', '24.832844')
# ('TAY', '58.307461', '26.690428')
# ('HEL', '60.317222', '24.963333')
# ('IVL', '68.607269', '27.405328')
# ('JOE', '62.662906', '29.60755')
# ('JYV', '62.399453', '25.678253')
# ('KEM', '65.781889', '24.5991')
# ('KAJ', '64.285472', '27.692414')
# ('KOK', '63.721172', '23.143131')
# ('KAO', '65.987575', '29.239381')
# ('KTT', '67.701022', '24.84685')
# ('KUO', '63.00715', '27.797756')
# ('LPP', '61.044553', '28.144397')
# ('MHQ', '60.122203', '19.898156')
# ('OUL', '64.930061', '25.354564')
# ('POR', '61.461686', '21.799983')
# ('RVN', '66.564822', '25.830411')
# ('SVL', '61.943064', '28.945136')
# ('TMP', '61.414147', '23.604392')
# ('TKU', '60.514142', '22.262808')
# ('VAA', '63.05065', '21.762175')
# ('BFS', '54.6575', '-6.215833')
# ('BHD', '54.618056', '-5.8725')
# ('LDY', '55.042778', '-7.161111')
# ('BHX', '52.453856', '-1.748028')
# ('GLO', '51.894167', '-2.167222')
# ('MAN', '53.353744', '-2.27495')
# ('NQY', '50.440558', '-4.995408')
# ('CWL', '51.396667', '-3.343333')
# ('BRS', '51.382669', '-2.719089')
# ('LPL', '53.333611', '-2.849722')
# ('LTN', '51.874722', '-0.368333')
# ('BOH', '50.78', '-1.8425')
# ('SOU', '50.950261', '-1.356803')
# ('ACI', '49.706111', '-2.214722')
# ('GCI', '49.434956', '-2.601969')
# ('JER', '49.207947', '-2.195508')
# ('LGW', '51.148056', '-0.190278')
# ('LCY', '51.505278', '0.055278')
# ('LHR', '51.4775', '-0.461389')
# ('SEN', '51.571389', '0.695556')
# ('BLK', '53.771667', '-3.028611')
# ('HUY', '53.574444', '-0.350833')
# ('LBA', '53.865897', '-1.660569')
# ('CEG', '53.178056', '-2.977778')
# ('IOM', '54.083333', '-4.623889')
# ('NCL', '55.0375', '-1.691667')
# ('MME', '54.509189', '-1.429406')
# ('EMA', '52.831111', '-1.328056')
# ('KOI', '58.957778', '-2.905')
# ('LSI', '59.878889', '-1.295556')
# ('WIC', '58.458889', '-3.093056')
# ('ABZ', '57.201944', '-2.197778')
# ('INV', '57.5425', '-4.0475')
# ('GLA', '55.871944', '-4.433056')
# ('EDI', '55.95', '-3.3725')
# ('ILY', '55.681944', '-6.256667')
# ('PIK', '55.509444', '-4.586667')
# ('BEB', '57.481111', '-7.362778')
# ('DND', '56.452499', '-3.025833')
# ('SYY', '58.215556', '-6.331111')
# ('TRE', '56.499167', '-6.869167')
# ('NWI', '52.675833', '1.282778')
# ('STN', '51.885', '0.235')
# ('EXT', '50.734444', '-3.413889')
# ('MPN', '-51.822777', '-58.447222')
# ('AMS', '52.308613', '4.763889')
# ('MST', '50.911658', '5.770144')
# ('EIN', '51.450139', '5.374528')
# ('GRQ', '53.11972', '6.579444')
# ('RTM', '51.956944', '4.437222')
# ('ORK', '51.841269', '-8.491111')
# ('DUB', '53.421333', '-6.270075')
# ('NOC', '53.910297', '-8.818492')
# ('KIR', '52.180878', '-9.523783')
# ('SNN', '52.701978', '-8.924817')
# ('WAT', '52.1872', '-7.086964')
# ('AAR', '56.300017', '10.619008')
# ('BLL', '55.740322', '9.151778')
# ('CPH', '55.617917', '12.655972')
# ('EBJ', '55.525942', '8.553403')
# ('KRP', '56.297458', '9.124628')
# ('RNN', '55.063267', '14.759558')
# ('SGD', '54.964367', '9.791731')
# ('FAE', '62.063628', '-7.277219')
# ('AAL', '57.092789', '9.849164')
# ('LUX', '49.626575', '6.211517')
# ('AES', '62.560372', '6.110164')
# ('ANX', '69.2925', '16.144167')
# ('ALF', '69.976111', '23.371667')
# ('BNN', '65.461111', '12.2175')
# ('BOO', '67.269167', '14.365278')
# ('BGO', '60.293386', '5.218142')
# ('BJF', '70.600278', '29.6925')
# ('KRS', '58.204214', '8.085369')
# ('BDU', '69.055758', '18.540356')
# ('EVE', '68.4913', '16.678108')
# ('VDB', '61.015556', '9.288056')
# ('FRO', '61.583611', '5.024722')
# ('OSL', '60.193917', '11.100361')
# ('HAU', '59.345267', '5.208364')
# ('HAA', '70.486675', '22.139744')
# ('KSU', '63.111781', '7.824522')
# ('KKN', '69.725781', '29.891295')
# ('MOL', '62.744722', '7.2625')
# ('MJF', '65.783997', '13.214914')
# ('LKL', '70.068814', '24.973489')
# ('OLA', '63.698908', '9.604003')
# ('RRS', '62.578411', '11.342347')
# ('RYG', '59.378933', '10.785389')
# ('LYR', '78.246111', '15.465556')
# ('SKE', '59.185', '9.566944')
# ('SRP', '59.791925', '5.34085')
# ('SSJ', '65.956828', '12.468944')
# ('TOS', '69.683333', '18.918919')
# ('TRF', '59.186703', '10.258628')
# ('TRD', '63.457556', '10.92425')
# ('SVG', '58.876778', '5.637856')
# ('GDN', '54.377569', '18.466222')
# ('KRK', '50.077731', '19.784836')
# ('KTW', '50.474253', '19.080019')
# ('POZ', '52.421031', '16.826325')
# ('RZE', '50.109958', '22.019')
# ('SZZ', '53.584731', '14.902206')
# ('WAW', '52.16575', '20.967122')
# ('WRO', '51.102683', '16.885836')
# ('RNB', '56.266667', '15.265')
# ('GOT', '57.662836', '12.279819')
# ('JKG', '57.757594', '14.068731')
# ('GSE', '57.774722', '11.870372')
# ('THN', '58.318056', '12.345')
# ('MXX', '60.957908', '14.511383')
# ('NYO', '58.788636', '16.912189')
# ('KID', '55.921686', '14.085536')
# ('KLR', '56.685531', '16.287578')
# ('MMX', '55.530193', '13.371639')
# ('HAD', '56.691128', '12.820211')
# ('VXO', '56.929144', '14.727994')
# ('EVG', '62.047811', '14.42295')
# ('GEV', '67.132408', '20.814636')
# ('KRF', '63.048597', '17.768856')
# ('LYC', '64.548322', '18.716219')
# ('SDL', '62.528125', '17.443928')
# ('OER', '63.408339', '18.990039')
# ('KRN', '67.821986', '20.336764')
# ('SFT', '64.624772', '21.076892')
# ('UME', '63.791828', '20.282758')
# ('VHM', '64.579083', '16.833575')
# ('AJR', '65.590278', '19.281944')
# ('ORB', '59.223733', '15.037956')
# ('VST', '59.589444', '16.633611')
# ('LLA', '65.543758', '22.121989')
# ('ARN', '59.651944', '17.918611')
# ('BMA', '59.354372', '17.94165')
# ('BLE', '60.422017', '15.515211')
# ('LPI', '58.40615', '15.680508')
# ('NRK', '58.586253', '16.250622')
# ('VBY', '57.662797', '18.346211')
# ('RLG', '53.918167', '12.278333')
# ('BFN', '-29.092722', '26.302444')
# ('CPT', '-33.964806', '18.601667')
# ('DUR', '-29.970089', '30.950519')
# ('ELS', '-33.035569', '27.825939')
# ('GRJ', '-34.005553', '22.378889')
# ('HDS', '-24.368642', '31.048744')
# ('JNB', '-26.139166', '28.246')
# ('KIM', '-28.802834', '24.765167')
# ('HLA', '-25.938514', '27.926133')
# ('MGH', '-30.857408', '30.343019')
# ('PLZ', '-33.984919', '25.617275')
# ('PHW', '-23.937166', '31.15539')
# ('PTG', '-23.926089', '29.484422')
# ('PZB', '-29.648975', '30.398667')
# ('RCB', '-28.741039', '32.092111')
# ('UTN', '-28.399097', '21.260239')
# ('UTT', '-31.547903', '28.674289')
# ('FRW', '-21.159597', '27.474525')
# ('BBK', '-17.832875', '25.1624')
# ('MUB', '-19.972564', '23.431086')
# ('GBE', '-24.555225', '25.918208')
# ('BZV', '-4.2517', '15.253031')
# ('PNR', '-4.816028', '11.886597')
# ('MTS', '-26.529022', '31.307519')
# ('BGF', '4.398475', '18.518786')
# ('BSG', '1.905469', '9.805681')
# ('SSG', '3.755267', '8.708717')
# ('MRU', '-20.430235', '57.6836')
# ('RRG', '-19.757658', '63.360983')
# ('DLA', '4.006081', '9.719481')
# ('MVR', '10.451392', '14.257361')
# ('NGE', '7.357011', '13.559242')
# ('GOU', '9.335892', '13.370103')
# ('LVI', '-17.821756', '25.822692')
# ('LUN', '-15.330817', '28.452628')
# ('MFU', '-13.258878', '31.936581')
# ('NLA', '-12.998139', '28.664944')
# ('HAH', '-11.533661', '43.27185')
# ('DZA', '-12.804722', '45.281113')
# ('RUN', '-20.8871', '55.510308')
# ('ZSE', '-21.320039', '55.423581')
# ('TNR', '-18.79695', '47.478806')
# ('SMS', '-17.093889', '49.815834')
# ('TMM', '-18.109517', '49.392536')
# ('MOQ', '-20.28475', '44.317614')
# ('DIE', '-12.3494', '49.291747')
# ('WMR', '-16.1639', '49.773753')
# ('ANM', '-14.999411', '50.320233')
# ('MJN', '-15.667144', '46.351828')
# ('NOS', '-13.312067', '48.314822')
# ('WMN', '-15.436666', '49.688332')
# ('SVB', '-14.278611', '50.174721')
# ('FTU', '-25.038056', '46.956111')
# ('TLE', '-23.383369', '43.728453')
# ('SSY', '-6.269897', '14.247025')
# ('CAB', '-5.596992', '12.188353')
# ('CPX', '18.3127', '-65.3034')
# ('NOV', '-12.808878', '15.760547')
# ('SVP', '-12.404633', '16.947414')
# ('LAD', '-8.858375', '13.231178')
# ('MEG', '-9.525086', '16.312406')
# ('SPP', '-14.657583', '17.719833')
# ('VHC', '-9.689067', '20.431875')
# ('SZA', '-6.141086', '12.371764')
# ('SDD', '-14.924733', '13.575022')
# ('LUO', '-11.768086', '19.897672')
# ('POG', '-0.711739', '8.754383')
# ('LBV', '0.4586', '9.412283')
# ('TMS', '0.378175', '6.712153')
# ('BEW', '-19.796419', '34.907556')
# ('INH', '-23.876431', '35.408544')
# ('VXC', '-13.273986', '35.266262')
# ('MPM', '-25.920836', '32.572606')
# ('APL', '-15.105611', '39.2818')
# ('POL', '-12.986753', '40.522492')
# ('UEL', '-17.8555', '36.869106')
# ('TET', '-16.104817', '33.640181')
# ('VNX', '-22.018431', '35.313297')
# ('SEZ', '-4.674342', '55.521839')
# ('PRI', '-4.319292', '55.691417')
# ('NDJ', '12.133689', '15.034019')
# ('BUQ', '-20.017431', '28.617869')
# ('VFA', '-18.095881', '25.839006')
# ('HRE', '-17.931806', '31.092847')
# ('BLZ', '-15.679053', '34.974014')
# ('LLW', '-13.789378', '33.781')
# ('MSU', '-29.462256', '27.552503')
# ('FIH', '-4.38575', '15.444569')
# ('MDK', '0.0226', '18.288744')
# ('GMA', '3.235369', '19.771258')
# ('FKI', '0.5175', '25.155014')
# ('IRP', '2.827606', '27.588253')
# ('BUX', '1.565719', '30.220833')
# ('BKY', '-2.308978', '28.808803')
# ('GOM', '-1.670814', '29.238464')
# ('KND', '-2.919178', '25.915361')
# ('FBM', '-11.591333', '27.530889')
# ('KGA', '-5.900055', '22.469166')
# ('MJM', '-6.121236', '23.569008')
# ('BKO', '12.533544', '-7.949944')
# ('BJL', '13.337961', '-16.652206')
# ('FUE', '28.452717', '-13.863761')
# ('VDE', '27.814847', '-17.887056')
# ('SPC', '28.626478', '-17.755611')
# ('LPA', '27.931886', '-15.386586')
# ('ACE', '28.945464', '-13.605225')
# ('TFS', '28.044475', '-16.572489')
# ('TFN', '28.482653', '-16.341536')
# ('MLN', '35.279817', '-2.956256')
# ('FNA', '8.616444', '-13.195489')
# ('MLW', '6.289061', '-10.758722')
# ('ROB', '6.233789', '-10.362311')
# ('AGA', '30.381353', '-9.546311')
# ('TTA', '28.448194', '-11.161347')
# ('FEZ', '33.927261', '-4.977958')
# ('OUD', '34.78715', '-1.923986')
# ('RBA', '34.051467', '-6.751519')
# ('CMN', '33.367467', '-7.589967')
# ('RAK', '31.606886', '-8.0363')
# ('OZZ', '30.939053', '-6.909431')
# ('AHU', '35.177103', '-3.839525')
# ('TTU', '35.594333', '-5.320019')
# ('TNG', '35.726917', '-5.916889')
# ('ZIG', '12.555617', '-16.281783')
# ('CSK', '12.4102', '-16.746125')
# ('DKR', '14.739708', '-17.490225')
# ('NKC', '18.097856', '-15.947956')
# ('NDB', '20.933067', '-17.029956')
# ('SID', '16.741389', '-22.949444')
# ('BVC', '16.136531', '-22.888897')
# ('MMO', '15.155928', '-23.213703')
# ('SNE', '16.588356', '-24.284656')
# ('VXE', '16.833689', '-25.054661')
# ('ADD', '8.977889', '38.799319')
# ('AMH', '6.039389', '37.590453')
# ('AXU', '14.14675', '38.772833')
# ('BJR', '11.608075', '37.321644')
# ('DIR', '9.6247', '41.854203')
# ('GMB', '8.128764', '34.563131')
# ('GDQ', '12.5199', '37.434047')
# ('JIM', '7.666094', '36.816639')
# ('LLI', '11.975014', '38.979969')
# ('MQX', '13.467367', '39.533464')
# ('ASO', '10.01855', '34.586253')
# ('BJM', '-3.324019', '29.318519')
# ('HGA', '9.518167', '44.088758')
# ('BBO', '10.389167', '44.941106')
# ('ABS', '22.375953', '31.611722')
# ('CAI', '30.121944', '31.405556')
# ('HRG', '27.178317', '33.799436')
# ('LXR', '25.671028', '32.706583')
# ('ASW', '23.964356', '32.819975')
# ('EDL', '0.404458', '35.238928')
# ('KIS', '-0.086139', '34.728892')
# ('KTL', '0.971989', '34.958556')
# ('LOK', '3.121967', '35.608692')
# ('LAU', '-2.252417', '40.913097')
# ('MBA', '-4.034833', '39.59425')
# ('WIL', '-1.321719', '36.814833')
# ('WJR', '1.733239', '40.091606')
# ('GHT', '25.145564', '10.142647')
# ('AKF', '24.178728', '23.313958')
# ('BEN', '32.096786', '20.269472')
# ('TIP', '32.663544', '13.159011')
# ('LTD', '30.151695', '9.715305')
# ('KGL', '-1.968628', '30.13945')
# ('KME', '-2.462242', '28.90795')
# ('ELF', '13.614892', '25.32465')
# ('JUB', '4.872006', '31.601117')
# ('KRT', '15.589497', '32.553161')
# ('ARK', '-3.367794', '36.633333')
# ('DAR', '-6.878111', '39.202625')
# ('JRO', '-3.429406', '37.074461')
# ('MYW', '-10.339058', '40.181781')
# ('MWZ', '-2.444486', '32.932667')
# ('ZNZ', '-6.222025', '39.224886')
# ('EBB', '0.042386', '32.443503')
# ('TIA', '41.414742', '19.720561')
# ('BOJ', '42.569583', '27.515236')
# ('PDV', '42.067806', '24.850833')
# ('SOF', '42.695194', '23.406167')
# ('VAR', '43.232072', '27.825106')
# ('LCA', '34.875117', '33.62485')
# ('PFO', '34.718039', '32.485731')
# ('DBV', '42.561353', '18.268244')
# ('OSI', '45.462667', '18.810156')
# ('PUY', '44.893533', '13.922192')
# ('RJK', '45.216889', '14.570267')
# ('SPU', '43.538944', '16.297964')
# ('ZAG', '45.742931', '16.068778')
# ('ZAD', '44.108269', '15.346697')
# ('ALC', '38.282169', '-0.558156')
# ('LEI', '36.843936', '-2.370097')
# ('OVD', '43.563567', '-6.034622')
# ('BIO', '43.301097', '-2.910608')
# ('BCN', '41.297078', '2.078464')
# ('BJZ', '38.89125', '-6.821333')
# ('LCG', '43.302061', '-8.377256')
# ('GRO', '41.900969', '2.760547')
# ('GRX', '37.188731', '-3.777356')
# ('IBZ', '38.872858', '1.373117')
# ('XRY', '36.744622', '-6.060111')
# ('MJV', '37.774972', '-0.812389')
# ('MAD', '40.493556', '-3.566764')
# ('AGP', '36.6749', '-4.499106')
# ('MAH', '39.862597', '4.218647')
# ('PNA', '42.770039', '-1.646331')
# ('REU', '41.147392', '1.167172')
# ('SLM', '40.952117', '-5.501986')
# ('EAS', '43.356519', '-1.790611')
# ('SCQ', '42.896333', '-8.415144')
# ('VLC', '39.489314', '-0.481625')
# ('VLL', '41.706111', '-4.851944')
# ('VGO', '42.2318', '-8.626775')
# ('SDR', '43.427064', '-3.820006')
# ('ZAZ', '41.666242', '-1.041553')
# ('SVQ', '37.418', '-5.893106')
# ('AGF', '44.174721', '0.590556')
# ('BOD', '44.828335', '-0.715556')
# ('EGC', '44.825279', '0.518611')
# ('PIS', '46.587745', '0.306666')
# ('LIG', '45.862778', '1.179444')
# ('TLS', '43.629075', '1.363819')
# ('PUF', '43.38', '-0.418611')
# ('LDE', '43.178675', '-0.006439')
# ('ANG', '45.729247', '0.221456')
# ('BVE', '45.150833', '1.469167')
# ('PGX', '45.198055', '0.815556')
# ('BIQ', '43.468419', '-1.523325')
# ('DCM', '43.55625', '2.289183')
# ('RDZ', '44.407869', '2.482672')
# ('DLE', '47.039014', '5.42725')
# ('LPY', '45.080689', '3.762889')
# ('ETZ', '48.982142', '6.251319')
# ('BIA', '42.552664', '9.483731')
# ('CLY', '42.530753', '8.793189')
# ('FSC', '41.500557', '9.097777')
# ('AJA', '41.923637', '8.802917')
# ('CFE', '45.786661', '3.169169')
# ('LYS', '45.726387', '5.090833')
# ('AUR', '44.891388', '2.421944')
# ('EBU', '45.540554', '4.296389')
# ('CCF', '43.215978', '2.306317')
# ('MRS', '43.435555', '5.213611')
# ('NCE', '43.658411', '7.215872')
# ('PGF', '42.740442', '2.870667')
# ('MPL', '43.576194', '3.963014')
# ('BZR', '43.323522', '3.353903')
# ('AVN', '43.9073', '4.901831')
# ('BVA', '49.454444', '2.112778')
# ('LEH', '49.533889', '0.088056')
# ('XCR', '48.776072', '4.184492')
# ('TUF', '47.432222', '0.727606')
# ('CDG', '49.012779', '2.55')
# ('ORY', '48.725278', '2.359444')
# ('LIL', '50.561942', '3.089444')
# ('BES', '48.447911', '-4.418539')
# ('DNR', '48.587683', '-2.079958')
# ('DOL', '49.365339', '0.154306')
# ('LRT', '47.760555', '-3.44')
# ('CFR', '49.173333', '-0.45')
# ('RNS', '48.069508', '-1.734794')
# ('LAI', '48.754378', '-3.471656')
# ('UIP', '47.974981', '-4.167786')
# ('NTE', '47.153189', '-1.610725')
# ('MLH', '47.589583', '7.529914')
# ('DIJ', '47.26889', '5.09')
# ('SXB', '48.538319', '7.628233')
# ('TLN', '43.0973', '6.14603')
# ('FNI', '43.757444', '4.416347')
# ('FSP', '46.762904', '-56.173088')
# ('AXD', '40.855869', '25.956264')
# ('VOL', '39.219619', '22.794339')
# ('JKH', '38.343175', '26.140572')
# ('IOA', '39.696388', '20.8225')
# ('HER', '35.339719', '25.180297')
# ('KSO', '40.446294', '21.282186')
# ('KIT', '36.274258', '23.016978')
# ('EFL', '38.120069', '20.500481')
# ('KLX', '37.068319', '22.025525')
# ('KGS', '36.793335', '27.091667')
# ('AOK', '35.421408', '27.146008')
# ('CFU', '39.601944', '19.911667')
# ('KSJ', '35.421358', '26.910047')
# ('KVA', '40.913306', '24.619223')
# ('LRS', '37.184903', '26.800289')
# ('LXS', '39.917072', '25.236308')
# ('JMK', '37.435128', '25.348103')
# ('MJT', '39.056667', '26.598333')
# ('PVK', '38.925467', '20.765311')
# ('RHO', '36.405419', '28.086192')
# ('GPA', '38.151111', '21.425556')
# ('CHQ', '35.531747', '24.149678')
# ('JSI', '39.1771', '23.503675')
# ('SMI', '37.689999', '26.911667')
# ('JTR', '36.399169', '25.479333')
# ('JSH', '35.216108', '26.101325')
# ('SKU', '38.967553', '24.487228')
# ('SKG', '40.519725', '22.97095')
# ('ZTH', '37.750853', '20.88425')
# ('BUD', '47.436933', '19.255592')
# ('DEB', '47.488917', '21.615333')
# ('BRI', '41.138856', '16.760594')
# ('PSR', '42.431656', '14.181067')
# ('BDS', '40.657633', '17.947033')
# ('SUF', '38.905394', '16.242269')
# ('CTA', '37.466781', '15.0664')
# ('LMP', '35.497914', '12.618083')
# ('PNL', '36.816519', '11.968864')
# ('PMO', '38.175958', '13.091019')
# ('REG', '38.071206', '15.651556')
# ('TPS', '37.911403', '12.487961')
# ('AHO', '40.632133', '8.290772')
# ('CAG', '39.251469', '9.054283')
# ('OLB', '40.898661', '9.517628')
# ('MXP', '45.630606', '8.728111')
# ('BGY', '45.673889', '9.704166')
# ('TRN', '45.200761', '7.649631')
# ('GOA', '44.413333', '8.8375')
# ('LIN', '45.445103', '9.276739')
# ('PMF', '44.824483', '10.296367')
# ('CUF', '44.547019', '7.623217')
# ('BZO', '46.460194', '11.326383')
# ('BLQ', '44.535444', '11.288667')
# ('TSF', '45.6484', '12.194422')
# ('TRS', '45.8275', '13.472222')
# ('RMI', '44.020292', '12.611747')
# ('VRN', '45.395706', '10.888533')
# ('VCE', '45.505278', '12.351944')
# ('CIA', '41.799361', '12.594936')
# ('FCO', '41.804475', '12.250797')
# ('EBA', '42.760277', '10.239445')
# ('NAP', '40.886033', '14.290781')
# ('PSA', '43.683917', '10.39275')
# ('FLR', '43.809953', '11.2051')
# ('PEG', '43.095906', '12.513222')
# ('LJU', '46.223686', '14.457611')
# ('KLV', '50.202978', '12.914983')
# ('OSR', '49.696292', '18.111053')
# ('PED', '50.013419', '15.738647')
# ('PRG', '50.100833', '14.26')
# ('BRQ', '49.151269', '16.694433')
# ('TLV', '32.011389', '34.886667')
# ('ETH', '29.561281', '34.960081')
# ('HFA', '32.809444', '35.043056')
# ('VDA', '29.94025', '34.93585')
# ('SDV', '32.114661', '34.782239')
# ('MLA', '35.857497', '14.4775')
# ('GRZ', '46.991067', '15.439628')
# ('INN', '47.260219', '11.343964')
# ('LNZ', '48.233219', '14.187511')
# ('SZG', '47.793304', '13.004333')
# ('VIE', '48.110278', '16.569722')
# ('SMA', '36.97139', '-25.170639')
# ('FLW', '39.455272', '-31.131361')
# ('FAO', '37.014425', '-7.965911')
# ('GRW', '39.092169', '-28.029847')
# ('HOR', '38.519894', '-28.715872')
# ('TER', '38.761842', '-27.090797')
# ('PDL', '37.741184', '-25.69787')
# ('PIX', '38.554333', '-28.441333')
# ('OPO', '41.248055', '-8.681389')
# ('PXO', '33.073386', '-16.349975')
# ('LIS', '38.781311', '-9.135919')
# ('SJZ', '38.6655', '-28.175817')
# ('PDT', '45.695', '-118.841389')
# ('OMO', '43.2829', '17.845878')
# ('SJJ', '43.824583', '18.331467')
# ('ARW', '46.17655', '21.262022')
# ('BAY', '47.658389', '23.470022')
# ('CND', '44.362222', '28.488333')
# ('CLJ', '46.785167', '23.686167')
# ('CRA', '44.318139', '23.888611')
# ('IAS', '47.178492', '27.620631')
# ('OMR', '47.025278', '21.9025')
# ('OTP', '44.572161', '26.102178')
# ('SBZ', '45.785597', '24.091342')
# ('SUJ', '47.703275', '22.8857')
# ('TGM', '46.467714', '24.412525')
# ('TSR', '45.809861', '21.337861')
# ('GVA', '46.238064', '6.10895')
# ('LUG', '46.004275', '8.910578')
# ('BRN', '46.9141', '7.497153')
# ('ZRH', '47.464722', '8.549167')
# ('ACH', '47.485033', '9.560775')
# ('ESB', '40.128082', '32.995083')
# ('ADA', '36.982166', '35.280388')
# ('AYT', '36.898731', '30.800461')
# ('GZT', '36.947183', '37.478683')
# ('KYA', '37.979', '32.561861')
# ('MZH', '40.829375', '35.521992')
# ('VAS', '39.813828', '36.903497')
# ('MLX', '38.435347', '38.091006')
# ('ASR', '38.770386', '35.495428')
# ('DNZ', '37.785567', '29.701297')
# ('IST', '40.976922', '28.814606')
# ('ADB', '38.292392', '27.156953')
# ('DLM', '36.713056', '28.7925')
# ('RIW', '43.064167', '-108.459722')
# ('EZS', '38.606925', '39.291417')
# ('DIY', '37.893897', '40.201019')
# ('ERC', '39.710203', '39.527003')
# ('ERZ', '39.956501', '41.170166')
# ('TZX', '40.995108', '39.789728')
# ('MTJ', '38.509794', '-107.894242')
# ('VAN', '38.468219', '43.3323')
# ('BAL', '37.928969', '41.116583')
# ('KIV', '46.927744', '28.930978')
# ('SKP', '41.961622', '21.621381')
# ('GIB', '36.151219', '-5.349664')
# ('BEG', '44.818444', '20.309139')
# ('TGD', '42.359392', '19.251894')
# ('PRN', '42.572778', '21.035833')
# ('TIV', '42.404664', '18.723286')
# ('BTS', '48.170167', '17.212667')
# ('KSC', '48.663055', '21.241112')
# ('PLS', '21.773625', '-72.265886')
# ('XSC', '21.515739', '-71.528528')
# ('LRM', '18.450711', '-68.911833')
# ('PUJ', '18.567367', '-68.363431')
# ('POP', '19.7579', '-70.570033')
# ('SDQ', '18.429664', '-69.668925')
# ('STI', '19.406092', '-70.604689')
# ('GUA', '14.583272', '-90.527475')
# ('LCE', '15.742481', '-86.853036')
# ('SAP', '15.452639', '-87.923556')
# ('GJA', '16.445367', '-85.906611')
# ('RTB', '16.316814', '-86.522961')
# ('TGU', '14.060883', '-87.217197')
# ('KIN', '17.935667', '-76.7875')
# ('MBJ', '18.503717', '-77.913358')
# ('ACA', '16.757061', '-99.753953')
# ('AGU', '21.705558', '-102.317858')
# ('HUX', '15.775317', '-96.262572')
# ('CME', '18.653739', '-91.799017')
# ('CUL', '24.764547', '-107.474717')
# ('CTM', '18.504667', '-88.326847')
# ('CEN', '27.392639', '-109.833111')
# ('CPE', '19.816794', '-90.500314')
# ('CJS', '31.636133', '-106.428667')
# ('CUU', '28.702875', '-105.964567')
# ('CVM', '23.703336', '-98.956486')
# ('CZM', '20.522403', '-86.925644')
# ('DGO', '24.124194', '-104.528014')
# ('TPQ', '21.419453', '-104.842581')
# ('GDL', '20.5218', '-103.311167')
# ('HMO', '29.095858', '-111.047858')
# ('CLQ', '19.277011', '-103.577397')
# ('SLW', '25.549497', '-100.928669')
# ('LZC', '18.001731', '-102.220525')
# ('LMM', '25.685194', '-109.080806')
# ('BJX', '20.993464', '-101.480847')
# ('LAP', '24.072694', '-110.362475')
# ('LTO', '25.989194', '-111.348361')
# ('MAM', '25.769894', '-97.525311')
# ('MID', '20.936981', '-89.657672')
# ('MXL', '32.630634', '-115.241637')
# ('MLM', '19.849944', '-101.0255')
# ('MTT', '18.103419', '-94.580681')
# ('MEX', '19.436303', '-99.072097')
# ('MTY', '25.778489', '-100.106878')
# ('MZT', '23.161356', '-106.266072')
# ('NLD', '27.443918', '-99.57046')
# ('OAX', '16.999906', '-96.726639')
# ('PAZ', '20.602671', '-97.460839')
# ('PBC', '19.158144', '-98.371447')
# ('PDS', '28.627394', '-100.535211')
# ('UPN', '19.396692', '-102.039056')
# ('PVR', '20.680083', '-105.254167')
# ('PXM', '15.876861', '-97.089117')
# ('QRO', '20.617289', '-100.185658')
# ('REX', '26.008908', '-98.228513')
# ('SJD', '23.15185', '-109.721044')
# ('SLP', '22.254303', '-100.930806')
# ('TRC', '25.568278', '-103.410583')
# ('TGZ', '16.561822', '-93.026081')
# ('TIJ', '32.541064', '-116.970158')
# ('TAM', '22.29645', '-97.865931')
# ('TLC', '19.337072', '-99.566008')
# ('TAP', '14.794339', '-92.370025')
# ('CUN', '21.036528', '-86.877083')
# ('VSA', '17.997', '-92.817361')
# ('VER', '19.145931', '-96.187267')
# ('ZCL', '22.897112', '-102.68689')
# ('ZIH', '17.601569', '-101.460536')
# ('ZLO', '19.144778', '-104.558631')
# ('MGA', '12.141494', '-86.168178')
# ('BOC', '9.340853', '-82.250842')
# ('CHX', '9.458636', '-82.516806')
# ('DAV', '8.391003', '-82.434992')
# ('PAC', '8.973339', '-79.555583')
# ('PTY', '9.071364', '-79.383453')
# ('GLF', '8.653775', '-83.180544')
# ('LIR', '10.593289', '-85.544408')
# ('NOB', '9.97649', '-85.653')
# ('SJO', '9.993861', '-84.208806')
# ('PMZ', '8.951025', '-83.468583')
# ('XQP', '9.443164', '-84.129772')
# ('SAL', '13.440947', '-89.055728')
# ('CAP', '19.732989', '-72.194739')
# ('PAP', '18.58005', '-72.292542')
# ('CYO', '21.616453', '-81.545989')
# ('CMW', '21.420428', '-77.847433')
# ('SCU', '19.969769', '-75.835414')
# ('GAO', '20.085419', '-75.158328')
# ('HAV', '22.989153', '-82.409086')
# ('HOG', '20.785589', '-76.315108')
# ('SNU', '22.492192', '-79.943611')
# ('VRA', '23.034445', '-81.435278')
# ('CYB', '19.686981', '-79.882789')
# ('GCM', '19.292778', '-81.35775')
# ('MHH', '26.511406', '-77.083472')
# ('AXP', '22.441828', '-73.970858')
# ('TCB', '26.745336', '-77.391269')
# ('BIM', '25.699881', '-79.264656')
# ('GGT', '23.562631', '-75.877958')
# ('ELH', '25.474861', '-76.683489')
# ('GHB', '25.284706', '-76.331011')
# ('RSD', '24.8917', '-76.177739')
# ('FPO', '26.558686', '-78.695553')
# ('IGA', '20.975', '-73.666862')
# ('LGI', '23.179014', '-75.093597')
# ('SML', '23.581444', '-75.270475')
# ('MYG', '22.379528', '-73.0135')
# ('NAS', '25.038958', '-77.466231')
# ('ZSA', '24.063275', '-74.523967')
# ('BZE', '17.539144', '-88.308203')
# ('AIT', '-18.830922', '-159.764233')
# ('RAR', '-21.202739', '-159.805556')
# ('NAN', '-17.755392', '177.443378')
# ('SUV', '-18.043267', '178.559228')
# ('TBU', '-21.241214', '-175.149644')
# ('TRW', '1.381636', '173.147036')
# ('WLS', '-13.238281', '-176.199228')
# ('APW', '-13.829969', '-172.008336')
# ('PPG', '-14.331', '-170.7105')
# ('RUR', '-22.434069', '-151.360614')
# ('TUB', '-23.365353', '-149.524072')
# ('TIH', '-15.119617', '-148.230697')
# ('FAV', '-16.05415', '-145.656994')
# ('XMH', '-14.436764', '-146.070056')
# ('GMR', '-23.079861', '-134.890333')
# ('KKR', '-15.663333', '-146.884769')
# ('MKP', '-16.583919', '-143.658369')
# ('TKP', '-14.709544', '-145.245814')
# ('AXR', '-15.248289', '-146.616708')
# ('MVT', '-14.868055', '-148.717225')
# ('TKX', '-14.455781', '-145.024542')
# ('NHV', '-8.795603', '-140.228789')
# ('BOB', '-16.444378', '-151.751286')
# ('RGI', '-14.954283', '-147.6608')
# ('HUH', '-16.687242', '-151.021667')
# ('MOZ', '-17.489972', '-149.761869')
# ('HOI', '-18.074814', '-140.945886')
# ('MAU', '-16.426486', '-152.243669')
# ('RFP', '-16.722861', '-151.465856')
# ('VLI', '-17.699325', '168.319794')
# ('KNQ', '-21.053428', '164.837806')
# ('KOC', '-20.546314', '164.255625')
# ('LIF', '-20.7748', '167.239864')
# ('GEA', '-22.258278', '166.472806')
# ('MEE', '-21.481678', '168.037508')
# ('TOU', '-20.790028', '165.259486')
# ('UVE', '-20.640556', '166.572778')
# ('NOU', '-22.014553', '166.212972')
# ('AKL', '-37.008056', '174.791667')
# ('TUO', '-38.739723', '176.084444')
# ('CHC', '-43.489358', '172.532225')
# ('DUD', '-45.928055', '170.198333')
# ('GIS', '-38.663333', '177.978333')
# ('HKK', '-42.713611', '170.985278')
# ('HLZ', '-37.866661', '175.332056')
# ('KKE', '-35.262779', '173.911944')
# ('KAT', '-35.07', '173.285278')
# ('NPL', '-39.008611', '174.179167')
# ('NSN', '-41.298333', '173.221111')
# ('IVC', '-46.412408', '168.312992')
# ('PMR', '-40.320556', '175.616944')
# ('PPQ', '-40.904722', '174.989167')
# ('ZQN', '-45.021111', '168.739167')
# ('ROT', '-38.109167', '176.317222')
# ('TRG', '-37.671944', '176.19611')
# ('TIU', '-44.302778', '171.225278')
# ('BHE', '-41.518333', '173.870278')
# ('WHK', '-37.920556', '176.914167')
# ('WLG', '-41.327221', '174.805278')
# ('WRE', '-35.768333', '174.365')
# ('WSZ', '-41.738056', '171.580833')
# ('WAG', '-39.962222', '175.025278')
# ('HEA', '34.210017', '62.2283')
# ('KBL', '34.565853', '69.212328')
# ('KDH', '31.505756', '65.847822')
# ('MZR', '36.706914', '67.209678')
# ('BAH', '26.270834', '50.63361')
# ('AHB', '18.240367', '42.656625')
# ('HOF', '25.285306', '49.485189')
# ('ABT', '20.296139', '41.634277')
# ('BHH', '19.98435', '42.620881')
# ('DMM', '26.471161', '49.79789')
# ('GIZ', '16.901111', '42.585833')
# ('ELQ', '26.302822', '43.773911')
# ('URY', '31.411942', '37.279469')
# ('HAS', '27.437917', '41.686292')
# ('JED', '21.679564', '39.156536')
# ('MED', '24.553422', '39.705061')
# ('EAM', '17.611436', '44.419169')
# ('AQI', '28.335192', '46.125069')
# ('RAH', '29.626419', '43.490614')
# ('RUH', '24.95764', '46.698776')
# ('RAE', '30.906589', '41.138217')
# ('SHW', '17.466875', '47.121431')
# ('TUU', '28.365417', '36.618889')
# ('TIF', '21.483418', '40.544334')
# ('TUI', '31.692683', '38.7312')
# ('EJH', '26.198553', '36.476381')
# ('YNB', '24.144244', '38.06335')
# ('ABD', '30.371111', '48.228333')
# ('MRX', '30.556192', '49.151879')
# ('AWZ', '31.337431', '48.76195')
# ('BUZ', '28.944811', '50.834637')
# ('KIH', '26.526156', '53.980211')
# ('BDH', '26.532', '54.824847')
# ('KSH', '34.345853', '47.158128')
# ('SDG', '35.245856', '47.009247')
# ('RAS', '37.325314', '49.605817')
# ('THR', '35.689167', '51.313416')
# ('BND', '27.218317', '56.37785')
# ('KER', '30.274444', '56.951111')
# ('XBJ', '32.898056', '59.266111')
# ('RZR', '36.909908', '50.679589')
# ('SYZ', '29.539242', '52.589786')
# ('TBZ', '38.133889', '46.235')
# ('AZD', '31.904908', '54.276503')
# ('ZBR', '25.44335', '60.382114')
# ('ZAH', '29.475686', '60.906189')
# ('AMM', '31.722556', '35.993214')
# ('AQJ', '29.611619', '35.018067')
# ('KWI', '29.226567', '47.968928')
# ('BEY', '33.820931', '35.488389')
# ('AUH', '24.432972', '54.651138')
# ('AZI', '24.428333', '54.458084')
# ('DXB', '25.252778', '55.364444')
# ('FJR', '25.112225', '56.323964')
# ('SHJ', '25.328575', '55.51715')
# ('KHS', '26.170986', '56.240569')
# ('MCT', '23.593278', '58.284444')
# ('SLL', '17.038719', '54.091297')
# ('LYP', '31.365014', '72.994842')
# ('GWD', '25.233308', '62.329494')
# ('GIL', '35.918786', '74.333644')
# ('KHI', '24.906547', '67.160797')
# ('LHE', '31.521564', '74.403594')
# ('MJD', '27.335156', '68.143053')
# ('MUX', '30.203222', '71.419111')
# ('PJG', '26.954547', '64.132517')
# ('PEW', '33.993911', '71.514581')
# ('UET', '30.251369', '66.937764')
# ('RYK', '28.3839', '70.279572')
# ('ISB', '33.616653', '73.099233')
# ('SKZ', '27.721989', '68.791683')
# ('PZH', '31.358381', '69.463606')
# ('BSR', '30.549069', '47.662142')
# ('DOH', '25.261125', '51.565056')
# ('ROP', '14.174308', '145.242536')
# ('SPN', '15.119003', '145.729356')
# ('GUM', '13.48345', '144.795983')
# ('MAJ', '7.064758', '171.272022')
# ('KWA', '8.720122', '167.731661')
# ('CXI', '1.986161', '-157.349778')
# ('TKK', '7.461869', '151.843006')
# ('PNI', '6.9851', '158.208989')
# ('ROR', '7.367303', '134.544278')
# ('KSA', '5.356975', '162.958386')
# ('YAP', '9.498911', '138.082497')
# ('KNH', '24.427892', '118.359197')
# ('TTT', '22.754986', '121.101681')
# ('KHH', '22.577094', '120.350006')
# ('RMQ', '24.264668', '120.62058')
# ('TNN', '22.950361', '120.205778')
# ('MZG', '23.568669', '119.628311')
# ('TSA', '25.069722', '121.5525')
# ('TPE', '25.077731', '121.232822')
# ('HUN', '24.023725', '121.616906')
# ('NRT', '35.764722', '140.386389')
# ('MMJ', '36.166758', '137.922669')
# ('IBR', '36.181083', '140.415444')
# ('SHM', '33.662222', '135.364444')
# ('OBO', '42.733333', '143.217222')
# ('CTS', '42.7752', '141.692283')
# ('HKD', '41.77', '140.821944')
# ('MMB', '43.880606', '144.164053')
# ('SHB', '43.5775', '144.96')
# ('WKJ', '45.404167', '141.800833')
# ('IKI', '33.749027', '129.785417')
# ('UBJ', '33.93', '131.278611')
# ('TSJ', '34.284889', '129.33055')
# ('MBE', '44.303914', '143.404028')
# ('AKJ', '43.670833', '142.4475')
# ('FUJ', '32.666269', '128.832808')
# ('FUK', '33.585942', '130.450686')
# ('KOJ', '31.803397', '130.719408')
# ('KMI', '31.877222', '131.448611')
# ('OIT', '33.479444', '131.737222')
# ('KKJ', '33.845942', '131.034689')
# ('KMJ', '32.837319', '130.85505')
# ('NGS', '32.916944', '129.913611')
# ('ASJ', '28.430633', '129.712542')
# ('KMQ', '36.394611', '136.406544')
# ('TOY', '36.648333', '137.1875')
# ('HIJ', '34.436111', '132.919444')
# ('OKJ', '34.756944', '133.855278')
# ('IZO', '35.413611', '132.89')
# ('YGJ', '35.492222', '133.236389')
# ('KCZ', '33.546111', '133.669444')
# ('MYJ', '33.827222', '132.699722')
# ('ITM', '34.785528', '135.438222')
# ('TTJ', '35.530069', '134.166553')
# ('TKS', '34.132808', '134.606639')
# ('TAK', '34.214167', '134.015556')
# ('AOJ', '40.734722', '140.690833')
# ('GAJ', '38.411894', '140.371331')
# ('HNA', '39.428611', '141.135278')
# ('AXT', '39.615556', '140.218611')
# ('MSJ', '40.703222', '141.368364')
# ('SDJ', '38.139722', '140.916944')
# ('HAC', '33.115', '139.785833')
# ('OIM', '34.782033', '139.360306')
# ('HND', '35.552258', '139.779694')
# ('KWJ', '35.126389', '126.808889')
# ('RSU', '34.842328', '127.61685')
# ('CJU', '33.511306', '126.493028')
# ('PUS', '35.179528', '128.938222')
# ('USN', '35.593494', '129.351722')
# ('GMP', '37.558311', '126.790586')
# ('KPO', '35.987858', '129.420486')
# ('TAE', '35.894108', '128.658856')
# ('OKA', '26.195814', '127.645869')
# ('ISG', '24.344525', '124.186983')
# ('UEO', '26.363506', '126.713806')
# ('MMY', '24.782833', '125.295111')
# ('MNL', '14.508647', '121.019581')
# ('CBO', '7.165242', '124.209619')
# ('CGY', '8.415619', '124.611219')
# ('PAG', '7.827197', '123.458294')
# ('ZAM', '6.922419', '122.059633')
# ('TAC', '11.227628', '125.027758')
# ('BCD', '10.642511', '122.929617')
# ('DGT', '9.333714', '123.300472')
# ('ILO', '10.713044', '122.545297')
# ('KLO', '11.679431', '122.376294')
# ('PPS', '9.742119', '118.758731')
# ('SJI', '10.766044', '121.933439')
# ('PRA', '-31.794778', '-60.480361')
# ('ROS', '-32.903611', '-60.785')
# ('SFN', '-31.711666', '-60.811668')
# ('AEP', '-34.559175', '-58.415606')
# ('COR', '-31.323619', '-64.207953')
# ('MDZ', '-32.831717', '-68.792856')
# ('AFA', '-34.588314', '-68.403854')
# ('CTC', '-28.593214', '-65.750925')
# ('SDE', '-27.765617', '-64.310122')
# ('IRJ', '-29.381636', '-66.795839')
# ('TUC', '-26.840861', '-65.104944')
# ('UAQ', '-31.571472', '-68.418194')
# ('LUQ', '-33.273192', '-66.356422')
# ('RES', '-27.449986', '-59.056125')
# ('FMA', '-26.212722', '-58.228111')
# ('IGR', '-25.737281', '-54.473444')
# ('PSS', '-27.385839', '-55.970728')
# ('SLA', '-24.855978', '-65.486169')
# ('JUJ', '-24.392778', '-65.097778')
# ('CRD', '-45.785347', '-67.465508')
# ('EQS', '-42.90795', '-71.139472')
# ('REL', '-43.2105', '-65.270319')
# ('VDM', '-40.869222', '-63.000389')
# ('PMY', '-42.759161', '-65.102725')
# ('RGA', '-53.777667', '-67.749389')
# ('RGL', '-51.608875', '-69.312636')
# ('USH', '-54.843278', '-68.29575')
# ('BHI', '-38.724967', '-62.169317')
# ('MDQ', '-37.934167', '-57.573333')
# ('NQN', '-38.949', '-68.155711')
# ('RSA', '-36.588322', '-64.275694')
# ('BRC', '-41.151172', '-71.157542')
# ('CPC', '-40.075383', '-71.137294')
# ('CDJ', '-8.348347', '-49.301528')
# ('AQA', '-21.812', '-48.133028')
# ('AJU', '-10.984', '-37.070333')
# ('AFL', '-9.866092', '-56.106206')
# ('ARU', '-21.141342', '-50.424722')
# ('BEL', '-1.37925', '-48.476292')
# ('PLU', '-19.851181', '-43.950628')
# ('BSB', '-15.8711', '-47.918625')
# ('BVB', '2.846311', '-60.690069')
# ('CAC', '-25.000339', '-53.500764')
# ('CNF', '-19.63375', '-43.968856')
# ('CGR', '-20.468667', '-54.6725')
# ('XAP', '-27.134219', '-52.656553')
# ('CCM', '-28.725817', '-49.424739')
# ('CAW', '-21.698333', '-41.301669')
# ('CMG', '-19.011931', '-57.673053')
# ('CWB', '-25.528475', '-49.175775')
# ('CXJ', '-29.197064', '-51.187536')
# ('CGB', '-15.652931', '-56.116719')
# ('CZS', '-7.599906', '-72.769489')
# ('PPB', '-22.175056', '-51.424639')
# ('MAO', '-3.038611', '-60.049721')
# ('IGU', '-25.59615', '-54.487206')
# ('FLN', '-27.670489', '-48.547181')
# ('FEN', '-3.854928', '-32.423336')
# ('FOR', '-3.776283', '-38.532556')
# ('GIG', '-22.808903', '-43.243647')
# ('GYN', '-16.632033', '-49.220686')
# ('GRU', '-23.432075', '-46.469511')
# ('ATM', '-3.253906', '-52.253978')
# ('IOS', '-14.815964', '-39.033197')
# ('IPN', '-19.470722', '-42.487583')
# ('IMP', '-5.531292', '-47.46005')
# ('JPA', '-7.148381', '-34.950681')
# ('JOI', '-26.224453', '-48.797364')
# ('CPV', '-7.269917', '-35.896364')
# ('VCP', '-23.0075', '-47.134444')
# ('LDB', '-23.333625', '-51.130072')
# ('LAZ', '-13.262086', '-43.408114')
# ('MAB', '-5.368589', '-49.138025')
# ('MGF', '-23.476392', '-52.016406')
# ('MOC', '-16.706925', '-43.8189')
# ('MCZ', '-9.510808', '-35.791678')
# ('MCP', '0.050664', '-51.072178')
# ('NVT', '-26.879999', '-48.65139')
# ('GEL', '-28.281683', '-54.169139')
# ('NAT', '-5.911417', '-35.247717')
# ('POA', '-29.994428', '-51.171428')
# ('PFB', '-28.243989', '-52.326558')
# ('PET', '-31.718353', '-52.327689')
# ('PNZ', '-9.362411', '-40.569097')
# ('PVH', '-8.709294', '-63.902281')
# ('RBR', '-9.583', '-67.4836')
# ('REC', '-8.126794', '-34.923039')
# ('RIG', '-32.082617', '-52.166542')
# ('SDU', '-22.910461', '-43.163133')
# ('RAO', '-21.134167', '-47.774189')
# ('SJK', '-23.228172', '-45.862739')
# ('SLZ', '-2.585361', '-44.234139')
# ('CGH', '-23.626692', '-46.655375')
# ('SJP', '-20.816567', '-49.406511')
# ('SSA', '-12.910994', '-38.331044')
# ('TMT', '-1.4896', '-56.396803')
# ('THE', '-5.059942', '-42.823478')
# ('TFF', '-3.382944', '-64.724056')
# ('TBT', '-4.255669', '-69.935828')
# ('TUR', '-3.786008', '-49.720267')
# ('PAV', '-9.400878', '-38.250575')
# ('URG', '-29.782178', '-57.038189')
# ('UDI', '-18.882844', '-48.225594')
# ('UBA', '-19.765', '-47.964778')
# ('BVH', '-12.694375', '-60.098269')
# ('VIX', '-20.258056', '-40.286389')
# ('ARI', '-18.348531', '-70.338742')
# ('BBA', '-45.916058', '-71.689475')
# ('CJC', '-22.498175', '-68.903575')
# ('PUQ', '-53.002642', '-70.854586')
# ('IQQ', '-20.535222', '-70.181275')
# ('SCL', '-33.392975', '-70.785803')
# ('ANF', '-23.444478', '-70.4451')
# ('CCP', '-36.77265', '-73.063106')
# ('IPC', '-27.164792', '-109.421831')
# ('ZOS', '-40.611208', '-73.061042')
# ('LSC', '-29.916233', '-71.199522')
# ('ZCO', '-38.766819', '-72.637097')
# ('PMC', '-41.438886', '-73.093953')
# ('ZAL', '-39.649956', '-73.086111')
# ('OCC', '-0.462886', '-76.986842')
# ('CUE', '-2.889467', '-78.984397')
# ('GPS', '-0.453758', '-90.265914')
# ('GYE', '-2.157419', '-79.883558')
# ('XMS', '-2.299167', '-78.12075')
# ('MEC', '-0.946078', '-80.678808')
# ('UIO', '-0.141144', '-78.488214')
# ('ASU', '-25.23985', '-57.519133')
# ('AXM', '4.452775', '-75.766447')
# ('PUU', '0.505228', '-76.500836')
# ('BGA', '7.1265', '-73.184778')
# ('BOG', '4.701594', '-74.146947')
# ('BAQ', '10.889589', '-74.780819')
# ('BSC', '6.202917', '-77.394675')
# ('BUN', '3.819628', '-76.989767')
# ('CUC', '7.927567', '-72.511547')
# ('CTG', '10.442381', '-75.512961')
# ('CLO', '3.543222', '-76.381583')
# ('TCO', '1.814417', '-78.749228')
# ('CZU', '9.332742', '-75.285594')
# ('EJA', '7.024331', '-73.8068')
# ('FLA', '1.589189', '-75.564372')
# ('GPI', '2.570133', '-77.8986')
# ('IBE', '4.421608', '-75.1333')
# ('IPI', '0.861925', '-77.671764')
# ('LET', '-4.193549', '-69.943163')
# ('EOH', '6.219958', '-75.590519')
# ('MTR', '8.823744', '-75.825831')
# ('MVP', '1.253664', '-70.233878')
# ('MZL', '5.029597', '-75.464708')
# ('NVA', '2.95015', '-75.294')
# ('PCR', '6.184717', '-67.493164')
# ('PEI', '4.812675', '-75.739519')
# ('PPN', '2.4544', '-76.609319')
# ('PSO', '1.396247', '-77.291478')
# ('PVA', '13.356944', '-81.35833')
# ('MDE', '6.164536', '-75.423119')
# ('RCH', '11.526222', '-72.925958')
# ('SJE', '2.579694', '-72.639358')
# ('SMR', '11.11965', '-74.230647')
# ('ADZ', '12.583594', '-81.711192')
# ('SVI', '2.152175', '-74.76635')
# ('TME', '6.451081', '-71.760261')
# ('AUC', '7.068881', '-70.736925')
# ('UIB', '5.690758', '-76.641181')
# ('VUP', '10.435042', '-73.249506')
# ('VVC', '4.167875', '-73.613761')
# ('CBB', '-17.421058', '-66.177114')
# ('CIJ', '-11.040436', '-68.782972')
# ('LPB', '-16.513339', '-68.192256')
# ('POI', '-19.543069', '-65.723706')
# ('SRE', '-19.007083', '-65.288747')
# ('TJA', '-21.555736', '-64.701325')
# ('TDD', '-14.818739', '-64.918019')
# ('VVI', '-17.644756', '-63.135364')
# ('BYC', '-21.960925', '-63.651669')
# ('PBM', '5.452831', '-55.187783')
# ('CAY', '4.819808', '-52.360447')
# ('PCL', '-8.377939', '-74.574297')
# ('CIX', '-6.787475', '-79.828097')
# ('AYP', '-13.154819', '-74.204417')
# ('ANS', '-13.706408', '-73.350378')
# ('ATA', '-9.347444', '-77.598392')
# ('LIM', '-12.021889', '-77.114319')
# ('JUL', '-15.467103', '-70.158169')
# ('TBP', '-3.552528', '-80.381356')
# ('IQT', '-3.784739', '-73.308806')
# ('AQP', '-16.341072', '-71.583083')
# ('TRU', '-8.081411', '-79.108761')
# ('TPP', '-6.508742', '-76.373247')
# ('TCQ', '-18.053333', '-70.275833')
# ('PEM', '-12.613611', '-69.228611')
# ('PIU', '-5.20575', '-80.616444')
# ('CUZ', '-13.535722', '-71.938781')
# ('MVD', '-34.838417', '-56.030806')
# ('BLA', '10.107139', '-64.689161')
# ('BNS', '8.619575', '-70.220825')
# ('BRM', '10.042747', '-69.358619')
# ('CAJ', '6.231989', '-62.854433')
# ('CZE', '11.414867', '-69.681656')
# ('CUM', '10.450333', '-64.130472')
# ('LSP', '11.780775', '-70.151497')
# ('LFR', '8.239167', '-72.271028')
# ('MAR', '10.558208', '-71.727856')
# ('MRD', '8.582294', '-71.161186')
# ('PMV', '10.912926', '-63.967581')
# ('CCS', '10.603117', '-66.990583')
# ('MUN', '9.749067', '-63.1534')
# ('PYH', '5.619992', '-67.606103')
# ('PBL', '10.4805', '-68.073025')
# ('PZO', '8.288528', '-62.760361')
# ('SVZ', '7.840831', '-72.439742')
# ('STD', '7.565111', '-72.035125')
# ('SOM', '8.945147', '-64.151083')
# ('VLN', '10.149733', '-67.9284')
# ('VLV', '9.340797', '-70.584089')
# ('ANU', '17.136749', '-61.792667')
# ('BGI', '13.074603', '-59.492456')
# ('DOM', '15.547028', '-61.3')
# ('FDF', '14.591033', '-61.003175')
# ('SFG', '18.099914', '-63.047197')
# ('PTP', '16.265306', '-61.531806')
# ('GND', '12.004247', '-61.786192')
# ('STT', '18.337306', '-64.973361')
# ('STX', '17.701889', '-64.798556')
# ('BQN', '18.494861', '-67.129444')
# ('MAZ', '18.255694', '-67.148472')
# ('PSE', '18.008306', '-66.563028')
# ('SJU', '18.439417', '-66.001833')
# ('SKB', '17.311194', '-62.718667')
# ('SLU', '14.020228', '-60.992936')
# ('UVF', '13.733194', '-60.952597')
# ('AUA', '12.501389', '-70.015221')
# ('BON', '12.131044', '-68.268511')
# ('CUR', '12.188853', '-68.959803')
# ('EUX', '17.496492', '-62.979439')
# ('SXM', '18.040953', '-63.1089')
# ('AXA', '18.204834', '-63.055084')
# ('TAB', '11.149658', '-60.832194')
# ('POS', '10.595369', '-61.337242')
# ('EIS', '18.444834', '-64.542975')
# ('AET', '66.5519', '-152.6222')
# ('SVD', '13.144306', '-61.210861')
# ('ALA', '43.352072', '77.040508')
# ('TSE', '51.022222', '71.466944')
# ('DMB', '42.853611', '71.303611')
# ('FRU', '43.061306', '74.477556')
# ('OSS', '40.608989', '72.793269')
# ('CIT', '42.364167', '69.478889')
# ('YAK', '59.3012', '-139.3937')
# ('URA', '51.150833', '51.543056')
# ('PWQ', '52.195', '77.073889')
# ('PLX', '50.3513', '80.2344')
# ('AKX', '50.245833', '57.206667')
# ('GYD', '40.4675', '50.046667')
# ('YKS', '62.09325', '129.770672')
# ('MJZ', '62.534689', '114.038928')
# ('BQS', '50.425394', '127.412478')
# ('KHV', '48.528044', '135.188361')
# ('MQT', '46.353611', '-87.395278')
# ('GDX', '59.910989', '150.720439')
# ('PWE', '69.783283', '170.597006')
# ('PKC', '53.167889', '158.453669')
# ('UUS', '46.888672', '142.717531')
# ('VVO', '43.398953', '132.148017')
# ('HTA', '52.026317', '113.305556')
# ('BTK', '56.370556', '101.698331')
# ('IKT', '52.268028', '104.388975')
# ('UUD', '51.807764', '107.437644')
# ('KBP', '50.345', '30.894722')
# ('DOK', '48.073611', '37.739722')
# ('DNK', '48.357222', '35.100556')
# ('SIP', '45.052222', '33.975139')
# ('IEV', '50.401694', '30.449697')
# ('LWO', '49.8125', '23.956111')
# ('IMT', '45.8183611', '-88.1145556')
# ('ODS', '46.426767', '30.676464')
# ...
# ('PBO', '-23.1711', '117.745')
# ('CCK', '-12.1883', '96.8339')
# ('GOV', '-12.2694', '136.818')
# ('PKE', '-33.1314', '148.239')
# ('PLO', '-34.6053', '135.88')
# ('EDR', '-14.8967', '141.609')
# ('PQQ', '-31.4358', '152.863')
# ('PTJ', '-38.3181', '141.471')
# ('ULP', '-26.6122', '144.253')
# ('RMA', '-26.545', '148.775')
# ('SGO', '-28.0497', '148.595')
# ('XTG', '-27.9864', '143.811')
# ('WNR', '-25.4131', '142.667')
# ('WYA', '-33.0589', '137.514')
# ('WIN', '-22.3636', '143.086')
# ('BWT', '-40.9989', '145.731')
# ('NAY', '39.7825', '116.387778')
# ('CIF', '42.235', '118.908')
# ('CIH', '36.2475', '113.126')
# ('DAT', '40.0603', '113.482')
# ('HET', '40.851422', '111.824103')
# ('BAV', '40.56', '109.997')
# ('SJW', '38.280686', '114.6973')
# ('TGO', '43.5567', '122.2')
# ('HLH', '46.083', '122.017')
# ('XIL', '43.9156', '115.964')
# ('BHY', '21.5394', '109.294')
# ('CGD', '28.9189', '111.64')
# ('DYG', '29.1028', '110.443')
# ('MXZ', '24.35', '116.133')
# ('ZUH', '22.0064', '113.376')
# ('LZH', '24.2075', '109.391')
# ('ZHA', '21.2144', '110.358')
# ('ENH', '30.3203', '109.485')
# ('NNY', '32.9808', '112.615')
# ('XFN', '32.1506', '112.291')
# ('YIH', '30.671', '111.441')
# ('GOQ', '34.633', '98.867')
# ('IQN', '35.7997', '107.603')
# ('XNN', '36.5275', '102.043')
# ('ENY', '36.6369', '109.554')
# ('UYN', '38.2692', '109.731')
# ('LTI', '46.3764', '96.2211')
# ('BYN', '46.1633', '100.704')
# ('HVD', '47.9541', '91.6282')
# ('MXV', '49.6633', '100.099')
# ('DIG', '27.7936', '99.6772')
# ('LUM', '24.4011', '98.5317')
# ('SYM', '22.7933', '100.959')
# ('ZAT', '27.3256', '103.755')
# ('KOW', '25.8258', '114.912')
# ('JDZ', '29.3386', '117.176')
# ('JIU', '29.733', '115.983')
# ('JUZ', '28.9658', '118.899')
# ('LYG', '34.55', '119.25')
# ('HYN', '28.5622', '121.429')
# ('LYI', '35.0461', '118.412')
# ('JJN', '24.7964', '118.59')
# ('TXN', '29.7333', '118.256')
# ('WEF', '36.6467', '119.119')
# ('WUX', '31.4944', '120.429')
# ('WUS', '27.7019', '118.001')
# ('WNZ', '27.9122', '120.852')
# ('YNZ', '33.3856', '120.125')
# ('YIW', '29.3447', '120.032')
# ('HSN', '29.9342', '122.362')
# ('BPX', '30.5536', '97.1083')
# ('DAX', '31.3', '107.5')
# ('GYS', '32.3911', '105.702')
# ('LZO', '28.8522', '105.393')
# ('MIG', '31.4281', '104.741')
# ('NAO', '30.754', '106.062')
# ('LZY', '29.3033', '94.3353')
# ('WXN', '30.8361', '108.406')
# ('AKU', '41.2625', '80.2917')
# ('KCA', '41.7181', '82.9869')
# ('KRL', '41.6978', '86.1289')
# ('KRY', '45.617', '84.883')
# ('YIN', '43.9558', '81.3303')
# ('HEK', '50.25', '127.3')
# ('JMU', '46.843394', '130.465389')
# ('JNZ', '41.1014', '121.062')
# ('NDG', '47.239628', '123.918131')
# ('YNJ', '42.8828', '129.451258')
# ('ORH', '42.2673', '-71.8757')
# ('AQG', '30.5822', '117.0502')
# ('JGS', '26.8997', '114.7375')
# ('SHP', '39.9681', '119.731')
# ('YCU', '35.018', '110.993')
# ('LHW', '36.117', '103.617')
# ('JGN', '39.8569', '98.3414')
# ('DDG', '40.0255', '124.2866')
# ('DSN', '39.85', '110.033')
# ('PZI', '26.54', '101.799')
# ('DIB', '27.4839', '95.0169')
# ('GCW', '35.5925', '-113.4859')
# ('BLD', '35.5651', '-114.514')
# ('PVC', '42.071945', '-70.22139')
# ('LKE', '47.629', '-122.339')
# ('SBH', '17.9023', '-62.8324')
# ('TZA', '17.5344', '-88.298')
# ('TBW', '52.81', '41.48')
# ('FSZ', '34.796111', '138.189444')
# ('ERM', '-27.6619', '-52.2683')
# ('NVI', '40.1172', '65.1708')
# ('QSF', '36.1781', '5.32449')
# ('LRH', '46.1792', '-1.19528')
# ('JNG', '35.417', '116.533')
# ('OHE', '52.915', '122.427')
# ('IAR', '57.560666676667', '40.157369454444')
# ('RMT', '-22.637253', '-152.805192')
# ('UKX', '56.85', '105.7167')
# ('BNY', '-11.302', '159.8')
# ('EAT', '47.398', '-120.206')
# ('COQ', '48.1357', '114.646')
# ('TRO', '-31.8886', '152.514')
# ('OAG', '-33.3817', '149.133')
# ('GFN', '-29.7594', '153.03')
# ('HDM', '34.869167', '48.5525')
# ('YIF', '51.2117', '-58.6583')
# ('VQS', '18.1158', '-65.4227')
# ('TEQ', '41.13825', '27.919094')
# ('SIC', '42.0158', '35.0664')
# ('MSR', '38.747769', '41.661236')
# ('CKZ', '40.137722', '26.426777')
# ('AOE', '39.809858', '30.519378')
# ('MPA', '-17.6344', '24.1767')
# ('WVB', '-22.9799', '14.6453')
# ('PDP', '-34.855139', '-55.094278')
# ('SKT', '32.5356', '74.3639')
# ('YVB', '48.0711', '-65.4603')
# ('UAS', '0.530583', '37.5342')
# ('CHG', '41.5381', '120.435')
# ('WLH', '-15.412', '167.691')
# ('TGC', '2.17784', '111.202')
# ('LKH', '3.3', '114.783')
# ('EGN', '13.4817', '22.4672')
# ('TOG', '59.0528', '-160.397')
# ('PTH', '56.9591', '-158.633')
# ('KVC', '55.1163', '-162.266')
# ('IGG', '59.324', '-155.902')
# ('DHM', '32.1651', '76.2634')
# ('EGM', '-8.57889', '157.876')
# ('RGS', '42.357628', '-3.620764')
# ('LEN', '42.589', '-5.655556')
# ('DRG', '66.0696', '-162.766')
# ('MQM', '37.2233', '40.6317')
# ('TCG', '46.6725', '83.3408')
# ('LGQ', '0.093056', '-76.8675')
# ('PFQ', '39.603606', '47.8815')
# ('IIL', '33.586606', '46.404842')
# ('GBT', '36.909381', '54.401339')
# ('WUZ', '23.4567', '111.248')
# ('HMI', '42.8414', '93.6692')
# ('SDP', '55.315', '-160.523')
# ('GOP', '26.739708', '83.449708')
# ('ACR', '-0.58', '-72.41')
# ('HGR', '39.7079', '-77.7295')
# ('QBC', '52.3875', '-126.596')
# ('PJA', '67.2456', '23.0689')
# ('GVR', '-18.8952', '-41.9822')
# ('KVK', '67.4633', '33.5883')
# ('CYZ', '16.929861', '121.753036')
# ('TMU', '9.73852', '-85.0138')
# ('FON', '10.478', '-84.6345')
# ('QOW', '5.42706', '7.20603')
# ('ARC', '68.1147', '-145.579')
# ('YTQ', '58.6678', '-69.9558')
# ('YPX', '60.0506', '-77.2869')
# ('WTK', '67.5661', '-162.975')
# ('SVA', '63.6864', '-170.493')
# ('SHH', '66.2496', '-166.089')
# ('RBY', '64.7272', '-155.47')
# ('PHO', '68.3488', '-166.799')
# ('MYU', '60.3714', '-166.271')
# ('KVL', '67.7362', '-164.563')
# ('KSM', '62.0605', '-163.302')
# ('KAL', '64.3191', '-158.741')
# ('HPB', '61.5239', '-166.147')
# ('GAM', '63.7668', '-171.733')
# ('ATK', '70.4673', '-157.436')
# ('ANV', '62.6467', '-160.191')
# ('AKP', '68.1336', '-151.743')
# ('AAT', '47.866667', '88.116667')
# ('NZH', '49.566667', '117.329444')
# ('WUA', '39.794444', '106.799444')
# ('BRD', '46.398308', '-94.138078')
# ('LWB', '37.858333', '-80.399444')
# ('PGV', '35.635278', '-77.385278')
# ('CYF', '60.149167', '-164.285556')
# ('BKG', '36.531994', '-93.200556')
# ('TEN', '27.884', '109.31')
# ('NBC', '55.34', '52.06')
# ('QRW', '5.31', '5.45')
# ('UST', '29.959167', '-81.339722')
# ('STS', '38.508978', '-122.81288')
# ('ASE', '39.2232', '-106.869')
# ('HHH', '32.216', '-80.752')
# ('ULV', '54.268299', '48.2267')
# ('TVF', '48.065556', '-96.185')
# ('CZH', '18.3822', '-88.4119')
# ('GDZ', '44.566666666667', '38.016666666667')
# ('GUC', '38.533889', '-106.933056')
# ('MBL', '44.2725', '-86.246944')
# ('PGD', '26.919722', '-81.990556')
# ('JHW', '42.153333', '-79.258056')
# ('SHD', '38.263889', '-78.896389')
# ('DIK', '46.7975', '-102.801944')
# ('SDY', '47.706944', '-104.1925')
# ('CDR', '42.8375', '-103.095556')
# ('AIA', '42.053333', '-102.803889')
# ('MCK', '40.206389', '-100.592222')
# ('GDV', '47.138611', '-104.807222')
# ('OLF', '48.094444', '-105.575')
# ('ALS', '37.435', '-105.866667')
# ('CNY', '38.755', '-109.754722')
# ('VEL', '40.440833', '-109.51')
# ('SOW', '34.265556', '-110.005556')
# ('MMH', '37.624049', '-118.837772')
# ('FRD', '48.521944', '-123.024444')
# ('ESD', '48.708056', '-122.910556')
# ('EMK', '62.786111', '-164.490833')
# ('UNK', '63.888333', '-160.798889')
# ('SHX', '62.692222', '-159.569167')
# ('CHU', '61.579167', '-159.215556')
# ('NUI', '70.21', '-151.005556')
# ('EEK', '60.213611', '-162.043889')
# ('KUK', '60.873333', '-162.524444')
# ('KWT', '60.790278', '-161.443611')
# ('KWK', '59.876389', '-163.168611')
# ('MLL', '61.8646418', '-162.026111')
# ('RSH', '61.775', '-161.319444')
# ('WTL', '60.335278', '-162.666944')
# ('KLL', '59.128056', '-156.858611')
# ('CIK', '66.645', '-143.74')
# ('HUS', '66.039167', '-154.264722')
# ('HSL', '65.697778', '-156.351389')
# ('MNT', '65.143611', '-149.37')
# ('NUL', '64.729444', '-158.074167')
# ('RMP', '65.507778', '-150.140833')
# ('TAL', '65.179556', '-152.075833')
# ('VEE', '67.008611', '-146.366389')
# ('WBQ', '66.362222', '-147.406667')
# ('CEM', '65.573889', '-144.780833')
# ('SHG', '66.888056', '-157.1625')
# ('KBC', '66.256708', '-145.815319')
# ('CXF', '67.251389', '-150.176111')
# ('VIS', '36.318611', '-119.392778')
# ('MCE', '37.284722', '-120.513889')
# ('TWB', '-27.542778', '151.916389')
# ('AGN', '57.503611', '-134.585')
# ('ELV', '58.195278', '-136.3475')
# ('TKE', '57.779722', '-135.218333')
# ('PEC', '57.955278', '-136.236389')
# ('EXI', '58.420556', '-135.449167')
# ('HNH', '58.096111', '-135.409722')
# ('CGA', '55.478889', '-133.147778')
# ('HYL', '55.481667', '-132.646111')
# ('MTM', '55.131111', '-131.578056')
# ('KTB', '55.688056', '-132.536667')
# ('HYG', '55.206389', '-132.828333')
# ('KPB', '56.351944', '-133.6225')
# ('PPV', '56.328889', '-133.61')
# ('WWP', '56.116389', '-133.121667')
# ('KCQ', '56.255', '-158.775278')
# ('EGX', '58.185556', '-157.375556')
# ('KCL', '56.311111', '-158.534167')
# ('KPV', '55.906667', '-159.160833')
# ('PIP', '57.585393', '-157.571944')
# ('WSN', '58.702222', '-157.0025')
# ('AKK', '56.938611', '-154.1825')
# ('KLN', '57.535', '-153.976667')
# ('OLH', '57.218056', '-153.269722')
# ('KOZ', '57.922876', '-152.500511')
# ('ORI', '57.885278', '-152.846111')
# ('AOS', '57.471389', '-153.815278')
# ('KKB', '58.190833', '-152.370556')
# ('SYB', '58.166667', '-152.5')
# ('ABL', '67.106389', '-157.8575')
# ('BKC', '65.981667', '-161.149167')
# ('IAN', '66.975833', '-160.436667')
# ('OBU', '66.912222', '-156.897222')
# ('ORV', '66.8175', '-161.022222')
# ('WLK', '66.6', '-159.985833')
# ('KTS', '65.331389', '-166.465833')
# ('ELI', '64.615', '-162.270556')
# ('GLV', '64.550556', '-163.007222')
# ('TLA', '65.240278', '-166.339444')
# ('WAA', '65.6225', '-168.095')
# ('WMO', '64.689167', '-163.412778')
# ('KKA', '64.939444', '-161.154167')
# ('SMK', '63.49', '-162.110278')
# ('SKK', '64.371111', '-161.223889')
# ('WBB', '63.515833', '-162.278056')
# ('TNC', '65.563056', '-167.921667')
# ('AKB', '52.220278', '-174.206389')
# ('IKO', '52.941667', '-168.848889')
# ('AUK', '62.68', '-164.66')
# ('SXP', '62.520556', '-164.847778')
# ('KPN', '59.933056', '-164.030556')
# ('KFP', '54.8475', '-163.410278')
# ('NLG', '56.0075', '-161.160278')
# ('KLW', '55.579167', '-133.076111')
# ('KWN', '59.755', '-161.845278')
# ('KOT', '63.030556', '-163.532778')
# ('KYU', '64.875833', '-157.730556')
# ('SCM', '61.845278', '-165.571389')
# ('NUP', '60.905833', '-162.439167')
# ('KKH', '59.960833', '-162.881111')
# ('NIB', '63.010833', '-154.383889')
# ('TCT', '62.971944', '-156.082778')
# ('PQS', '61.934444', '-162.899444')
# ('AKI', '60.902778', '-161.230556')
# ('TLT', '61.096944', '-160.969444')
# ('KGX', '62.894444', '-160.065')
# ('AIN', '70.638056', '-159.994722')
# ('IRC', '65.827778', '-144.076111')
# ('KCC', '56.014722', '-132.833889')
# ('CKD', '61.867778', '-158.135')
# ('RDV', '61.788056', '-157.350278')
# ('SLQ', '61.700566', '-157.165833')
# ('SRV', '61.7875', '-156.591111')
# ('HKB', '63.8675', '-148.968889')
# ('KAE', '56.973056', '-133.945556')
# ('MLY', '64.9975', '-150.644167')
# ('STG', '56.577222', '-169.663611')
# ('YSO', '54.910278', '-59.785278')
# ('YWB', '61.588611', '-71.929444')
# ('YGV', '50.281944', '-63.611389')
# ('YOP', '58.491389', '-119.407778')
# ('ZEL', '52.139722', '-128.063611')
# ('DGA', '16.966667', '-88.216667')
# ('PLJ', '16.536944', '-88.361667')
# ('SSB', '17.747222', '-64.705')
# ('UYU', '-20.466667', '-66.833333')
# ('RBQ', '-14.4275', '-67.498056')
# ('RVE', '6.916667', '-71.9')
# ('LCR', '-0.733333', '-73.016667')
# ('LMC', '2.179167', '-73.7875')
# ('VGZ', '0.978889', '-76.605556')
# ('CFB', '-22.921667', '-42.074167')
# ('OPS', '-11.885', '-55.586')
# ('GRP', '-11.728889', '-49.068889')
# ('PIN', '-2.627778', '-56.735833')
# ('BRA', '-12.083333', '-45')
# ('STZ', '-10.47', '-50.502778')
# ('MQH', '-13.526944', '-48.220556')
# ('AUX', '-7.228333', '-48.240833')
# ('DOU', '-22.220833', '-54.805833')
# ('ROO', '-16.466667', '-54.633333')
# ('GPB', '-25.383333', '-51.45')
# ('JCB', '-27.172778', '-51.500833')
# ('RVD', '-17.790278', '-50.918333')
# ('AAX', '-19.563056', '-46.960278')
# ('CIZ', '-4.085', '-63.140833')
# ('BAZ', '-0.975', '-62.923889')
# ('GNM', '-14.216667', '-42.783333')
# ('JIJ', '9.359722', '42.7875')
# ('MRE', '-1.406111', '35.008056')
# ('NBE', '36.075833', '10.438611')
# ('PAF', '2.3275', '31.5')
# ('HTY', '36.362778', '36.282222')
# ('RVV', '-23.87', '-147.67')
# ('FUO', '23.133333', '113.28333')
# ('ILD', '41.727778', '0.535833')
# ('ULG', '48.991667', '89.919722')
# ('BVV', '44.92', '147.621667')
# ('OHH', '53.583333', '142.933333')
# ('NJF', '31.991667', '44.404167')
# ('FUG', '32.9', '115.816667')
# ('LCX', '25.674167', '116.746389')
# ('BSD', '25.053333', '99.168333')
# ('ACX', '25.0882', '104.9587')
# ('HZH', '26.206', '109.039')
# ('HJJ', '27.441389', '109.699722')
# ('LNJ', '23.738333', '100.025')
# ('WNH', '23.375833', '104.243056')
# ('SJL', '-0.148056', '-66.9858')
# ('CKS', '-6.11781', '-50.0035')
# ('ITB', '-4.2446', '-56.00384')
# ('PGU', '27.379444', '52.7375')
# ('YES', '30.700556', '51.545')
# ('ULO', '49.973333', '92.079722')
# ('DIW', '5.966667', '80.683333')
# ('TJU', '37.981667', '69.799444')
# ('RVT', '-33.797222', '120.208056')
# ('PVU', '40.21805555', '-111.72222222')
# ('LAM', '35.8798019', '-106.2694153')
# ('RNA', '-9.854722', '161.979167')
# ('CHY', '-6.711944', '156.396111')
# ('NNB', '-10.848056', '162.454167')
# ('NDU', '-17.956461', '19.719439')
# ('AGM', '65.612222', '-37.618333')
# ('MMU', '40.79935', '-74.4148747')
# ('ECP', '30.3417', '-85.7973')
# ('LTX', '-0.5425', '-78.3657')
# ('MYQ', '12.3072', '76.6497')
# ('OAL', '47.78', '10.627')
# ('ONQ', '41.506111', '32.088611')
# ('TCZ', '24.938651', '98.483591')
# ('UKS', '44.691431', '33.57567')
# ('YUS', '32.825', '97.125')
# ('PYC', '9.303333', '-78.236111')
# ('HIA', '33.7772', '119.1478')
# ('PVE', '9.559167', '-78.971111')
# ('NGQ', '32.10027', '80.052778')
# ('PUE', '8.68333', '-77.5333')
# ('UKA', '-4.29694', '39.5714')
# ('YZY', '55.29944', '-123.08333')
# ('ZHY', '37.5728', '105.1544')
# ('DWC', '24.55056', '55.103174')
# ('AEB', '23.72', '106.96')
# ('NYT', '19.374', '96.121')
# ('RCE', '48.608056', '-123.159722')
# ('WSX', '48.617778', '-122.952778')
# ('FBS', '48.537222', '-123.009722')
# ('IZA', '-21.5130558014', '-43.1730575562')
# ('NME', '60.471111', '-164.700833')
# ('OOK', '60.541389', '-165.087222')
# ('TNK', '60.575556', '-165.271667')
# ('GNU', '59.1175', '-161.5775')
# ('WWT', '60.939167', '-164.641111')
# ('ACU', '9.2', '-77.98')
# ('GHE', '8.06', '-78.36')
# ('MPP', '8.95', '-77.75')
# ('OBY', '70.485278', '-21.966667')
# ('VIN', '49.2433', '28.6063')
# ('ZKG', '50.195833', '-61.265833')
# ('YZZ', '49.055556', '-117.609167')
# ('YAB', '73.006389', '-85.047222')
# ('BCV', '17.269444', '-88.776111')
# ('HMB', '26.341189', '31.742983')
# ('POJ', '-18.672778', '-46.491111')
# ('JTC', '-22.157778', '-49.068333')
# ('OIA', '-6.763056', '-51.05')
# ('RDC', '-8.033333', '-49.98')
# ('SXX', '-6.641389', '-51.952222')
# ('BYO', '-21.247222', '-56.4525')
# ('SXO', '-11.6325', '-50.689444')
# ('CFC', '-26.788333', '-50.939722')
# ('ERN', '-6.639444', '-69.879722')
# ('OLC', '-3.465556', '-68.918889')
# ('IRZ', '-0.416944', '-65.033889')
# ('GZP', '36.2993', '32.3014')
# ('KEW', '52.991111', '-92.836389')
# ('ULH', '26.636718', '37.908018')
# ('LOP', '-8.7573222', '116.276675')
# ('HDG', '36.524', '114.43')
# ('WMI', '52.451111', '20.651667')
# ('JXA', '45.30611', '130.99667')
# ('EYK', '63.683056', '66.683056')
# ('ELL', '-23.666667', '27.75')
# ('UMD', '70.4047', '52.0702')
# ('RLK', '40.926389', '107.738889')
# ('PUM', '-4.183333', '121.61667')
# ('RGK', '51.966667', '85.833333')
# ('LLK', '38.746389', '48.817778')
# ('GBB', '40.826667', '47.7125')
# ('JIQ', '29.515', '108.83')
# ('DEE', '43.5739', '145.4107')
# ('NBS', '42.088056', '127.548889')
# ('LUZ', '51.239333', '22.714083')
# ('LLF', '26.345556', '111.612222')
# ('TVS', '39.717444', '118.002389')
# ('YTY', '32.5617', '119.715')
# ('GKK', '0.7308', '73.433')
# ('RHD', '-27.509946', '-64.936666')
# ('KGT', '30.1575', '101.734722')
# ('VUS', '60.788333', '46.26')
# ('ODO', '57.5137', '114.1348')
# ('HRI', '6.284467', '81.124128')
# ('XSB', '24.2856083', '52.5783472')
# ('ZDY', '24.5033833', '52.3360528')
# ('JGD', '50.375', '124.117')
# ('BFJ', '27.253', '105.426')
# ('ULK', '60.723', '114.825')
# ('IGD', '39.983056', '43.866389')
# ('GNY', '37.45', '38.9')
# ('KZR', '39.111389', '30.13')
# ('BQB', '-33.687222', '115.400278')
# ('YIC', '27.8033', '114.3081')
# ('THD', '19.90167', '105.46778')
# ('MJU', '-2.583333', '119.033333')
# ('GIU', '7.57212', '80.43412')
# ('BGG', '38.86111', '40.5925')
# ('KFS', '41.316944', '33.796111')
# ('DCY', '29.3231', '100.0533')
# ('GXH', '34.4909', '102.3719')
# ('CIY', '37', '14.6144')

# %% [markdown]
# ## Your turn
# Perform a similar query, but instead of source, change it to reflect destinations.

# %%
cursor.execute("""

""")
print(*cursor.fetchall(), sep='\n')

# %% [markdown]
# The default is **inner join**, which brings in all of the shared indexes across the tables. We can change the JOIN type to LEFT JOIN, which brings in all of the indices of the routes table, and matches them to the airports table.

# %%
cursor.execute("""
SELECT source, dest, a.name 
FROM routes r
LEFT JOIN airports a
ON r.source_id = a.id
LIMIT 10
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('AER', 'KZN', 'Sochi')
# ('ASF', 'KZN', 'Astrakhan')
# ('ASF', 'MRV', 'Astrakhan')
# ('CEK', 'KZN', 'Balandino')
# ('CEK', 'OVB', 'Balandino')
# ('DME', 'KZN', 'Domododevo')
# ('DME', 'NBC', 'Domododevo')
# ('DME', 'TGK', 'Domododevo')
# ('DME', 'UUA', 'Domododevo')
# ('EGO', 'KGD', 'Belgorod International Airport')

# %% [markdown]
# ## COUNT
# In the SELECT statement, we can use certain agregate operators such as COUNT, SUM, MIN, and MAX.
#
# Let's use count to better understand the different types of joins.
#
# Look at the difference between the counts when we use LEFT join vs INNER join

# %%
cursor.execute("""
SELECT COUNT(source_id)
FROM routes r
LEFT JOIN airports a
ON r.source_id = a.id
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# (67663,)

# %%
cursor.execute("""
SELECT COUNT(source_id)
FROM routes r
JOIN airports a
ON r.source_id = a.id
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# (67424,)

# %%
# Why is there a difference?  Let's look at the distince values of the routes source_id
cursor.execute("""
SELECT DISTINCT(source_id)
FROM routes r
ORDER BY source_id DESC
LIMIT 10 
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('\\N',)
# ('999',)
# ('995',)
# ('994',)
# ('990',)
# ('99',)
# ('988',)
# ('986',)
# ('985',)
# ('984',)

# %% [markdown]
# ### Now count the number of times \\\N occurs.

# %%
cursor.execute("""

""")
print(*cursor.fetchall(), sep='\n')

# %% [markdown]
# The count of \\\N should equal the difference in the two joins.  That is because a left join on routes brings in all indices from routes, but an inner join only brings in indices that match between the two tables.  The routes indices that equal '\\\N' are not present in the airports table.

# %% [markdown]
# ## Joining multiple tables

# %% [markdown]
# In order to fetch the airport names which American Airlines operates out of, we have to join both the routes table and the airports tables. Aliases become very important!

# %%
# Fill in the aliases in the query below to make the joins work correctly. 


cursor.execute("""
SELECT DISTINCT(p.name), a.name
FROM airlines
JOIN routes
ON a.id = r.airline_id
JOIN airports
ON r.source_id = p.id
WHERE a.name = 'American Airlines'
LIMIT 10
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-145-866261682dea> in <module>
#      11 WHERE a.name = 'American Airlines'
#      12 LIMIT 10
# ---> 13 """)
#      14 print(*cursor.fetchall(), sep='\n')
#
# OperationalError: no such column: p.name

# %%
# Now, create a new query which counts the number of airports United Airlines operates out of

# %% [markdown]
# ### Grouping statements
#
# Combines `select` and `group by` when you want aggregates by values

# %% [markdown]
# `select` `min(x)` ... `max()`, `sum()`, etc

# %% [markdown]
# `group by x`

# %% [markdown]
# GROUP BY must always be used with an aggregate

# %%
cursor.execute("""
SELECT
    country
  , count(*) AS airline_count
FROM airlines
WHERE active = 'Y'
GROUP BY 1
ORDER BY 2 DESC
LIMIT 10
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('United States', 141)
# ('Russia', 72)
# ('United Kingdom', 40)
# ('Germany', 37)
# ('Canada', 34)
# ('Australia', 26)
# ('China', 25)
# ('Spain', 24)
# ('Brazil', 23)
# ('France', 22)

# %%
# Let's count which airlines run the most routes

cursor.execute("""
SELECT
    a.name, COUNT(airline) as airline_count
FROM routes r
JOIN airlines a
on r.airline_id = a.id
GROUP BY airline
ORDER BY airline_count DESC
LIMIT 10
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('Ryanair', 2484)
# ('American Airlines', 2354)
# ('United Airlines', 2180)
# ('Delta Air Lines', 1981)
# ('US Airways', 1960)
# ('China Southern Airlines', 1454)
# ('China Eastern Airlines', 1263)
# ('Air China', 1260)
# ('Southwest Airlines', 1146)
# ('easyJet', 1130)

# %% [markdown]
# **Task**<br>
# - Which countries have the highest amount of active airlines?
# - Which countries have the highest amount of inactive airlines?
# - What about airports by timezones?

# %%
# Which countries have the highest amount of active airlines?
cursor.execute("""
SELECT
    country
  , count(*) AS airline_count
FROM airlines
WHERE active = 'Y'
GROUP BY 1
ORDER BY 2 DESC
LIMIT 10
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('United States', 141)
# ('Russia', 72)
# ('United Kingdom', 40)
# ('Germany', 37)
# ('Canada', 34)
# ('Australia', 26)
# ('China', 25)
# ('Spain', 24)
# ('Brazil', 23)
# ('France', 22)

# %%
cursor.description
# Out:
# (('country', None, None, None, None, None, None),
#  ('airline_count', None, None, None, None, None, None))

# %%
# Which countries have the highest amount of inactive airlnes?
cursor.execute("""
SELECT
    country
  , count(*) AS airline_count
FROM airlines
WHERE active = 'N'
GROUP BY country
ORDER BY count(*) DESC
LIMIT 10

""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('United States', 939)
# ('Mexico', 427)
# ('United Kingdom', 367)
# ('Canada', 284)
# ('Russia', 158)
# ('Spain', 142)
# ('France', 97)
# ('Germany', 94)
# ('South Africa', 81)
# ('Nigeria', 80)

# %%
# What about airports by timezones?
cursor.execute("""
SELECT
    timezone AS tz
  , count(*) AS a_cnt
FROM airports
GROUP BY 1
ORDER BY 2 DESC
LIMIT 10
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('America/New_York', 628)
# ('America/Chicago', 373)
# ('Europe/Berlin', 319)
# ('America/Anchorage', 258)
# ('Europe/Paris', 232)
# ('America/Los_Angeles', 226)
# ('Asia/Chongqing', 222)
# ('Europe/London', 193)
# ('America/Toronto', 159)
# ('Asia/Calcutta', 141)

# %% [markdown]
# ## Having
#
# Having is used with a GROUP BY, and filters the data based on a criteria in a similar way to the WHERE clause.
#
# Let's limit our counts

# %%
cursor.execute("""
SELECT
    a.name, COUNT(airline) as airline_count
FROM routes r
JOIN airlines a
on r.airline_id = a.id
GROUP BY airline
HAVING airline_count > 1000
ORDER BY airline_count DESC

""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('Ryanair', 2484)
# ('American Airlines', 2354)
# ('United Airlines', 2180)
# ('Delta Air Lines', 1981)
# ('US Airways', 1960)
# ('China Southern Airlines', 1454)
# ('China Eastern Airlines', 1263)
# ('Air China', 1260)
# ('Southwest Airlines', 1146)
# ('easyJet', 1130)
# ('Air France', 1071)

# %% [markdown]
# We can use many of the same operators we used with WHERE in the HAVING clause

# %%
cursor.execute("""
SELECT
    a.name, COUNT(airline) as airline_count
FROM routes r
JOIN airlines a
on r.airline_id = a.id
GROUP BY airline
HAVING a.name LIKE 'B%'
ORDER BY airline_count ASC
LIMIT 10
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('Benin Golf Air', 4)
# ('Berjaya Air', 4)
# ('BVI Airways', 6)
# ('bmibaby', 10)
# ('Belair Airlines', 12)
# ('BusinessAir', 12)
# ('BQB Lineas Aereas', 18)
# ('Big Sky Airlines', 36)
# ('Bearskin Lake Air Service', 39)
# ('Baikotovitchestrian Airlines ', 41)

# %%
# It's always a good idea to close our connections when we're done
# cursor.close()
# con.close()

# %% [markdown]
# ## Goal 4: Transfering from sqlite to pandas

# %%
pd_con = sqlite3.connect("flights.db")
df = pd.read_sql_query("select * from airports limit 5;", pd_con)
df

# %% [markdown]
# **Task**:
# Convert one of the earlier queries in the lesson to a pandas data frame

# %%
# Which countries have the highest amount of active airports?
df = pd.read_sql_query("""
-- your code here;
""", pd_con)
df

# %%
pd_con.close()
